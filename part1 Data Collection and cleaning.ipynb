# %% [markdown]
# # Part 1 - Data Collection and cleaning

# %%
# !pip install accelerate bitsandbytes transformers datasets music21 einops
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: music21 in /usr/local/lib/python3.12/dist-packages (9.9.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.9.0+cu126)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.12/dist-packages (from music21) (5.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from music21) (1.5.2)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.12/dist-packages (from music21) (4.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from music21) (3.10.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from music21) (10.8.0)
# Requirement already satisfied: webcolors>=1.5 in /usr/local/lib/python3.12/dist-packages (from music21) (25.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->music21) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->music21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->music21) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->music21) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->music21) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->music21) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->music21) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->music21) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 39.0 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.0

# %% [markdown]
# We installed several packages necessary for the extraction

# %% [markdown]
# First of all I am writing some necessary functions like creating batches from data, creating folders

# %%
import torch

def get_batch_from_data(dataset, size_of_the_block, batch_tokens=2_000_000):
    Batch = batch_tokens // size_of_the_block
    ix = torch.randint(len(dataset)-size_of_the_block-1, (B,))
    x = torch.stack([dataset[i:i+size_of_the_block] for i in ix])
    y = torch.stack([dataset[i+1:i+size_of_the_block+1] for i in ix])
    return x.cuda(), y.cuda()

# %%
import os

os.makedirs("mlproject/preprocess", exist_ok=True)
os.makedirs("mlproject/data/midi", exist_ok=True)
os.makedirs("mlproject/data/abc", exist_ok=True)
os.makedirs("mlproject/data/tokens", exist_ok=True)

print("Folders created successfully!")
# !ls -R mlproject
# Out:
# Folders created successfully!
# mlproject:
# data  preprocess
#
# mlproject/data:
# abc  midi  tokens
#
# mlproject/data/abc:
#
# mlproject/data/midi:
#
# mlproject/data/tokens:
#
# mlproject/preprocess:

# %% [markdown]
# Our dataset is coming as a .mid files, and for this task I need abc files which contains musical notations, octaves

# %%
# %%writefile mlproject/preprocess/midi_to_abc.py
import os
from pathlib import Path
from music21 import converter
from tqdm import tqdm

def midi_to_abc(input, output):
    input = Path(input)
    output = Path(output)
    output.mkdir(parents=True, exist_ok=True)

    files_obtained = list(input.rglob("*.mid")) + list(input.rglob("*.midi"))
    success, fail = 0, 0

    for f in tqdm(files_obtained, desc="Converting MIDI files into → ABC"):
        out_path = output / (f.stem + ".abc")
        try:
            score = converter.parse(f)
            score.write("abc", fp=str(out_path))
            success += 1
        except:
            fail += 1

    return {
        "total": len(files_obtained),
        "success": success,
        "failed": fail,
        "success_rate": success / max(len(files_obtained), 1)
    }
# Out:
# Writing mlproject/preprocess/midi_to_abc.py

# %%
# %%writefile mlproject/preprocess/utils.py
import json
from collections import Counter

def build_vocab(list_of_tokens, vocab_path):
    collectionsCounter = Counter()
    for tokens in list_of_tokens:
        collectionsCounter.update(tokens)

    most_common_vocabulary = {tok: i for i, (tok, _) in enumerate(collectionsCounter.most_common())}

    with open(vocab_path, "w") as f:
        json.dump(most_common_vocabulary, f)

    return most_common_vocabulary
# Out:
# Writing mlproject/preprocess/utils.py

# %%
# %%writefile mlproject/preprocess/build_dataset.py
import os
import json
import numpy as np
from pathlib import Path
from tqdm import tqdm
from .tokenize_abc import tokenize_abc
from .utils import build_vocab

def encoding_the_token(tokens, vobubulary):
    return [vobubulary[t] for t in tokens if t in vobubulary]

def build_dataset(abc_dir, output_dir, train_frac=0.98, val_frac=0.01):
    directory_abc = Path(abc_dir)
    output_dir = Path(output_dir)
    output_dir.mkdir(exist_ok=True, parents=True)

    files = list(directory_abc.rglob("*.abc"))
    token_lists = []

    print("Tokenizing ABC files for each text in progress...")
    for f in tqdm(files):
        try:
            text = f.read_text()
            tokens = tokenize_abc(text)
            if len(tokens) > 10:
                token_lists.append(tokens)
        except:
            pass

    print("Building the vocabulary from token_list ...")
    vocab = build_vocab(token_lists, output_dir / "vocab.json")

    encoded_token_list = [encoding_the_token(toks, vocab) for toks in token_lists]
    all_tokens = np.concatenate([np.array(e, dtype=np.uint32) for e in encoded_token_list])

    number_of_tokens = len(all_tokens)
    train_end = int(number_of_tokens * train_frac)
    val_end = int(number_of_tokens * (train_frac + val_frac))

    train = all_tokens[:train_end]
    val   = all_tokens[train_end:val_end]
    test  = all_tokens[val_end:]

    train.tofile(output_dir / "train.bin")
    val.tofile(output_dir / "val.bin")
    test.tofile(output_dir / "test.bin")

    stats = {
        "total_tokens": int(number_of_tokens),
        "train_tokens": int(len(train)),
        "val_tokens": int(len(val)),
        "test_tokens": int(len(test)),
        "vocab_size": len(vocab),
        "num_abc_files": len(files)
    }

    with open(output_dir / "stats.json", "w") as f:
        json.dump(stats, f, indent=2)

    return stats
# Out:
# Writing mlproject/preprocess/build_dataset.py

# %% [markdown]
# Here we wrote the functions to create json for the dataset and building the dataset from our raw files

# %%
# !ls -R mlproject/preprocess
# Out:
# mlproject/preprocess:
# build_dataset.py  midi_to_abc.py  utils.py

# %%
# !git lfs install
# !git clone https://huggingface.co/datasets/amaai-lab/MidiCaps mlproject/data/midicaps
# Out:
# Git LFS initialized.
# Cloning into 'mlproject/data/midicaps'...
# remote: Enumerating objects: 233, done.
# remote: Total 233 (delta 0), reused 0 (delta 0), pack-reused 233 (from 1)
# Receiving objects: 100% (233/233), 61.26 KiB | 20.42 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %% [markdown]
# I loaded the data from huggingface midicaps dataset which is an extended version of midi dataset.

# %%
# %cd mlproject/data/midicaps
# !git lfs install
# !git lfs pull
# %cd /content
# Out:
# /content/mlproject/data/midicaps
# Updated git hooks.
# Git LFS initialized.
# /content

# %%
# !tar -xvf mlproject/data/midicaps/midicaps.tar.gz -C mlproject/data/midicaps
# Out:
# Streaming output truncated to the last 5000 lines.
# lmd_full/4/4e30d7e3d1d6ee586eb9754017b5205d.mid
# lmd_full/4/4ead16e2ca5c380cb6c5097645bf789e.mid
# lmd_full/4/498f48f540720491810453dcf7daf3ff.mid
# lmd_full/4/4d020d6775b9c42d29705d1c9f0bd317.mid
# lmd_full/4/466d3a5158fcd62f669aa515a2cf57db.mid
# lmd_full/4/4f0100bf9b460f632413a54907839d10.mid
# lmd_full/4/491ced95c3348a5533c51782df041959.mid
# lmd_full/4/442c7a56d31582a7010562d453304e37.mid
# lmd_full/4/457e6071c01ee5a091f51690495fb9c5.mid
# lmd_full/4/434086b94ece79ff1b5a6a06baf79e46.mid
# lmd_full/4/4c4869b42a040d509252f39f647314f8.mid
# lmd_full/4/49cc0f692469af6e000ae15015caf13a.mid
# lmd_full/4/43d8c6191058f62a2e65dca5143cf45b.mid
# lmd_full/4/41d7f180ca573a454a940daae650b29b.mid
# lmd_full/4/4fa46b35a2ac225663fde17763bcf57f.mid
# lmd_full/4/49a0ba04546ad193a9fe32cd34a8eb41.mid
# lmd_full/4/480cf89a34536e03ff04b25172d9e917.mid
# lmd_full/4/4fc8f1612a342cbfa41014dd0368fb8c.mid
# lmd_full/4/47945ea8ab640114794244d786295c15.mid
# lmd_full/4/48b002662cdcf3aa4575e85c98dcfad2.mid
# lmd_full/4/45aae9507ac5c2a199a484ac15642905.mid
# lmd_full/4/47a372a080acae718edef2e407bc5022.mid
# lmd_full/4/4322b266c79a5fee53727f93325ca66b.mid
# lmd_full/4/400839d1a7588297b9642f42089649f5.mid
# lmd_full/4/4787f00399442bdcd79f5fd103a9b26b.mid
# lmd_full/4/4ae4ad430412439dc7c613ae805a4929.mid
# lmd_full/4/478205fc6ab3ac4375124f7feb8d5b53.mid
# lmd_full/4/416691bb295efe7bcd9001328d293623.mid
# lmd_full/4/4508808c41449704ecc8e588b994a018.mid
# lmd_full/4/43709feda30fb1f198a1a7b6cd4e4945.mid
# lmd_full/4/4fe46ffad959b1bd0f139e54e0bd01d4.mid
# lmd_full/4/42b13e250f0df8f882a158381b2293c6.mid
# lmd_full/4/41501e513bfa436ae210d2a2d0056510.mid
# lmd_full/4/42d9a0fa71aa0ca12bb62f9220d0cebc.mid
# lmd_full/4/48841409f94a7bc2b4d76ae4e506cde4.mid
# lmd_full/4/41449229fc1fa3049c0634589035d271.mid
# lmd_full/4/4b76064f54b196dcf7337b4a1aac9679.mid
# lmd_full/4/4ff5543e0781294d64a7c9e48e7d6b20.mid
# lmd_full/4/4d0e47bfe4dece680d8a745ab4196e64.mid
# lmd_full/4/41eabee28ea6301bb1fe157462383e1e.mid
# lmd_full/4/4a39e75aaa1863f2e30482cd1780f240.mid
# lmd_full/4/498581100b12d42855b1784b57d4e849.mid
# lmd_full/4/437223822bad6eed6e516ef3b0697a1a.mid
# lmd_full/4/4d7caf4a55209e2377d450b742d6abd8.mid
# lmd_full/4/4153e5b9ace5eb332f431e2a0b670c81.mid
# lmd_full/4/4663ac124c148653a5646746a473ecbd.mid
# lmd_full/4/48db1f4c603031ed346e489285cf2d33.mid
# lmd_full/4/4d3536949f81d900ed8310c98a7c1493.mid
# lmd_full/4/4d7a2cb0cc29f5ddd7e7908ba5d10a85.mid
# lmd_full/4/4023902615a9c741380bec5cf9855654.mid
# lmd_full/4/4c8b16e808dbe8156f82cc19aba8e86b.mid
# lmd_full/4/416e91feec2617d73ad729f2d8848b64.mid
# lmd_full/4/43b4129fc84fffb61aa6753f92d88015.mid
# lmd_full/4/43cf85c2aeb4144a365f1f944fb489a9.mid
# lmd_full/4/413f62a8f4bebe8a1b698f0b1bbebb07.mid
# lmd_full/4/4075d823dd986652adc9481c45a9bb65.mid
# lmd_full/4/462f0c2aa58667bdc2d639a07f2ce106.mid
# lmd_full/4/4eef505aefb938cc6ae349c68efb1c6a.mid
# lmd_full/4/436361ea32ed075ea9d3c8a91512b3eb.mid
# lmd_full/4/410bb7786fc17df586cb52cdc037a05f.mid
# lmd_full/4/43a71300dad04d7cc8223ad8d6a060cb.mid
# lmd_full/4/4f36786619dcd5f1319959b63e28ec12.mid
# lmd_full/4/431e3b9e99d06f464537382288c2c61b.mid
# lmd_full/4/42822161f2ea749e25ce54de4eaf4148.mid
# lmd_full/4/45435b011a66b5491b0c880393a9cf93.mid
# lmd_full/4/44394ff3753a71372799a372fadc2fc7.mid
# lmd_full/4/4c5b1a006c12cf6ed89f7f79a6e176e2.mid
# lmd_full/4/4c518b7e2dd5bd50e507d891475c85ab.mid
# lmd_full/4/4b45ab056490fd44f1f2604f1c3e99b6.mid
# lmd_full/4/4ea919cfb2ccd3f5a517ba30be550dae.mid
# lmd_full/4/40204c1f55a1659214df141881f37b14.mid
# lmd_full/4/4e4667d5d8006a3600c68a1688cee9b5.mid
# lmd_full/4/4effa4ec4b7380e9f659147d568ff0f4.mid
# lmd_full/4/424ec5e01147ec124280f178290e589b.mid
# lmd_full/4/42294c2ea48acdb4df7e291244557c6f.mid
# lmd_full/4/430c2ab2f766ee2191483534db7e392c.mid
# lmd_full/4/468be354b93cc113fc3d4c7480e840a7.mid
# lmd_full/4/410ac7442b6b4e99ee9b55455bec16d9.mid
# lmd_full/4/417a6752f96e2a5fa7e6e2322c9c99af.mid
# lmd_full/4/43f099f278d46c64983cf712365f3f88.mid
# lmd_full/4/40bd5c3b9523495fef49765ecb1c4ce9.mid
# lmd_full/4/4777b715fb8c3d0f1ee3f19deb69d140.mid
# lmd_full/4/4d8be0732d043deb2c04ff35406b8a62.mid
# lmd_full/4/473c26555cd11578d2c823f82fe3c989.mid
# lmd_full/4/42c9ec694c57af3675f7eab8bbae3aa9.mid
# lmd_full/4/42c219cf78280fc6cde899860c9c8ebe.mid
# lmd_full/4/4694200d2b0abc30c7740dfaf55f3698.mid
# lmd_full/4/4874a518d2922e9f88ae45fa5aff1289.mid
# lmd_full/4/4c41bf743fbb98fd05d9f32b3f286ff9.mid
# lmd_full/4/4b9b47d2e67a85573d1394d004da1395.mid
# lmd_full/4/4039763f07a0a06a566fa59f2d67dbd8.mid
# lmd_full/4/4659e38e3c5610aebef1c82731b12f82.mid
# lmd_full/4/4e10fe0b7ccfac474fcae0260c4852c7.mid
# lmd_full/4/4011096cd172784a2dcbd50e2083d8eb.mid
# lmd_full/4/43e1f096773add8232a1db9435583108.mid
# lmd_full/4/4b6d7971f1538786dbddb437939e214b.mid
# lmd_full/4/4d86523ddb49831b93bd454edd462f53.mid
# lmd_full/4/4ea4be0836d8b33484c516796c507f1e.mid
# lmd_full/4/4aaf483d927ec567782c4249eff931d7.mid
# lmd_full/4/4abf95381078bb71152bf91dd2a74a92.mid
# lmd_full/4/4aa79b1a04e9a1212b4c76439c53a62c.mid
# lmd_full/4/4215f44531bbb2dacff4c67b45ca24d9.mid
# lmd_full/4/44a10ef2cc1be17472ef962040efb983.mid
# lmd_full/4/4d938dc20b126d0c3867856ce3b53796.mid
# lmd_full/4/46963604472fae53f82467a118eb18fc.mid
# lmd_full/4/46060f3316069968bd19819088061c89.mid
# lmd_full/4/4415a86a3d44dcaeb3bc14419bc4237c.mid
# lmd_full/4/47a12bf9aa1dfd401b0f5c7e37f6f0c1.mid
# lmd_full/4/43cc1a2057ec875325fb71959906336f.mid
# lmd_full/4/486fc7e447a36a64171e24c61b600cab.mid
# lmd_full/4/414aae301685379b508e048bdd674a61.mid
# lmd_full/4/41a2d3c19f1c88a3d4db0fde92ca38ce.mid
# lmd_full/4/43eaf362aafa26cf916ae1c29970a9d3.mid
# lmd_full/4/4ac78b63c24ab0e5c175ef5acde03eab.mid
# lmd_full/4/4a5543923c85fc4ea927deea6a6c2e46.mid
# lmd_full/4/4313bb3cb72a02064693e9541487be52.mid
# lmd_full/4/40c61e26cbd8b2686db9715b89d2ef34.mid
# lmd_full/4/42764e0db98771cd4e749c28ab7d096d.mid
# lmd_full/4/4f25c9c9770549fd7dcee817f3a74fcd.mid
# lmd_full/4/4e1f23d2c87fefe239e31290e705c958.mid
# lmd_full/4/4e7366cbae832c2429ddc6f88e46ebd8.mid
# lmd_full/4/44700d46106b805816448eaea6e32a14.mid
# lmd_full/4/4a899e31fa4f0222fc57b3c768740f7c.mid
# lmd_full/4/4a88f6f79d87058bb78dd85a358737c9.mid
# lmd_full/4/4db19b7ece4784920f67fb710eeaaa32.mid
# lmd_full/4/444b4fc491350e3d3f3779ae9beb9387.mid
# lmd_full/4/471f4f95b32635b7afa497a163acd04e.mid
# lmd_full/4/4a8d98af673825d8274540ae68a0c451.mid
# lmd_full/4/4ec8fbd9f019b979d050121412bc0a0d.mid
# lmd_full/4/410cfde47be9bef2b9d98ed230cc86a9.mid
# lmd_full/4/456ca48f76c99216e045b845f1ea64b4.mid
# lmd_full/4/4a7bbdc1471d39e6980bee02a123fb43.mid
# lmd_full/4/47d5ada6b7af3375ff59efd2557eb9f4.mid
# lmd_full/4/4ecea0c407c023bab74223eaf78e02a0.mid
# lmd_full/4/4076654ec059dc1dd5f586a36e0bc623.mid
# lmd_full/4/46b9af5ed6c9afb267a778e6f382dd13.mid
# lmd_full/4/48110b4a6e40042942acea996aab0de8.mid
# lmd_full/4/4cb33a70360770c2ca4dc452174d838f.mid
# lmd_full/4/4706bf1c7876ad33a7e588c4fce36c5e.mid
# lmd_full/4/4996fe95016724efeb853b85a893f9cf.mid
# lmd_full/4/46f75016521d7b3c6561a3755307367b.mid
# lmd_full/4/4317302a4df39e9d1e15c7b0f2974bb7.mid
# lmd_full/4/4fdef8e245b9df08f34c84244393ce2a.mid
# lmd_full/4/4f8ae15d4921ddc147d6a9b9cfc6c424.mid
# lmd_full/4/432fb1419296679ca0770466bfcbad98.mid
# lmd_full/4/4b766696236cd82a842ee5f75abd8926.mid
# lmd_full/4/491928f3750ad3cc722495fb99a63d63.mid
# lmd_full/4/467dd1d30a5d7569cdca992919ed21a4.mid
# lmd_full/4/419dc2db0457917aabdce1ac25712130.mid
# lmd_full/4/4ced59b3e6bfde977cbcae72c0448e10.mid
# lmd_full/4/451fb55eb709febf059ef96b61de0110.mid
# lmd_full/4/40cd2da63cff29f614aac72b03625d04.mid
# lmd_full/4/4be5efd6fed911e8fabd0726fa1cf685.mid
# lmd_full/4/4eeb75f9a9984e07a7d23343598efd62.mid
# lmd_full/4/4ff0be7c9f12ee35db14788a7e8df545.mid
# lmd_full/4/4602782059f502430258e709cac4ebb2.mid
# lmd_full/4/4603a4f749794c0d42818bb4f3a2dbdd.mid
# lmd_full/4/40155f23b8ce5d5ed1d09940c3818340.mid
# lmd_full/4/464bbb101194dab862c09b428da66c4d.mid
# lmd_full/4/4a54afa98762dc7554294c8b3ec56667.mid
# lmd_full/4/48aff3de1fb1fa41ddcd7fcf09e112ef.mid
# lmd_full/4/486ab631aff463e04d2e19ffccb1d809.mid
# lmd_full/4/454bfae213a73018ec21c859b56b9aff.mid
# lmd_full/4/45d82b4d58769aa5926517ca9f40870f.mid
# lmd_full/4/4a372db8df822903b674ac54a54a2dfe.mid
# lmd_full/4/4fd482dc3278d5f477f41a00c1112cfc.mid
# lmd_full/4/48f25bc5c8306eb2fa609fdbe93cb7e0.mid
# lmd_full/4/48101e53f466bad79df9806bf0f27f56.mid
# lmd_full/4/49f7a5f88dd89468c70c5fa955a47297.mid
# lmd_full/4/497c1a310f1eae9e0cf1f1ee5567710b.mid
# lmd_full/4/4cc79285c9e778cf20204ffbff94320b.mid
# lmd_full/4/458c4bfa7a60e80687fa2ec2cc218b21.mid
# lmd_full/4/43ff03077ccfacf0aafce674531204c1.mid
# lmd_full/4/436fa7184e59e890570dd93f4ddab181.mid
# lmd_full/4/46eb45c2f6d4c029f4cf946a6eb57dd3.mid
# lmd_full/4/497ca88ae765472d25f8014a22cb9a28.mid
# lmd_full/4/46b32c08ece515d72e6f4527ae5c554c.mid
# lmd_full/4/4ed0951e281ac2659580a72c8aa3eb1f.mid
# lmd_full/4/410f2ac0736f220dc045058c54781cdc.mid
# lmd_full/4/4dcc1bb8c24b8e24646292109e2b4127.mid
# lmd_full/4/40ba896c10969d99aa9f00bcf7c31f84.mid
# lmd_full/4/4ef7421fe26e8cf505e8b15831a90d9d.mid
# lmd_full/4/437482a82026130d4929f1585bb19f46.mid
# lmd_full/4/44589238c4e05432437d26eee64e4e53.mid
# lmd_full/4/4621f4472c92a3c720361447e64fbb82.mid
# lmd_full/4/451a8fa5de822fa84e8ad969cacfc9b5.mid
# lmd_full/4/4c717906884d5ab8dba7e980e82272c2.mid
# lmd_full/4/46d248c7a2556520e0335f7b8abbae74.mid
# lmd_full/4/44f2b0dbbe61d42a87408f93d4b8f121.mid
# lmd_full/4/491d1443f31d95e9dff65981d9334ad1.mid
# lmd_full/4/4dd1f3baebe4a60f14e8d3f090200c83.mid
# lmd_full/4/42fd4e40a3bfa72cc7cbe08db7bfd08f.mid
# lmd_full/4/406aa68bfce743fb70aba2361b9ea5ea.mid
# lmd_full/4/40ce991b9839ffda908f60627578ce34.mid
# lmd_full/4/4e089c1fd082ab1397edbd5cb38e8bb1.mid
# lmd_full/4/418ed785db7a7a05d7dab8726bb58638.mid
# lmd_full/4/4e811e8495413af6e326e60b43185177.mid
# lmd_full/4/4fef33b21a4bf926348eda25f367af54.mid
# lmd_full/4/472a2999fc70038b45142c8531f6ba06.mid
# lmd_full/4/43d71892058ee109951ebfccd0a99dcf.mid
# lmd_full/4/4cebf55e27c3319815d4bb46bb909b33.mid
# lmd_full/4/49b112aed2fca13f4d08d4ed8aadffd7.mid
# lmd_full/4/457602961ffeb0e44bb492aa59adbb7d.mid
# lmd_full/4/4e3d591865408355350d6c9b7f1cf5fd.mid
# lmd_full/4/47a81c6a125359f42a80c05604a96d15.mid
# lmd_full/4/4bf0b29600b027789bde4e1c9e9bc49c.mid
# lmd_full/4/41dccf49ed5fed64e600e1f4e491e9e9.mid
# lmd_full/4/4f01e3004abe330a15e90f82d0b0997b.mid
# lmd_full/4/460a1fc170a46ba5ced31c7b02e9d32d.mid
# lmd_full/4/41e783039e3c32510a2a9a27f30a2569.mid
# lmd_full/4/4abeaac66f61342d4b57fb54e9a7cf9c.mid
# lmd_full/4/4d3b96779036ce34b510ff2cfc7ebf27.mid
# lmd_full/4/424e3942866bde49f55b292651352155.mid
# lmd_full/4/49bbbbe152d768b91bc28ac0a39015c9.mid
# lmd_full/4/45234f2d86d5d36e6fca7e0cf7d8c1e0.mid
# lmd_full/4/43b1dc38f61154f4825760da94e84e05.mid
# lmd_full/4/4ad09eb0e50245f6f782c7529402ec47.mid
# lmd_full/4/4aa9556132dbbdfe876c8e33fc19951c.mid
# lmd_full/4/4deaecc46434a47f3121771651f5dd2e.mid
# lmd_full/4/4f021e2950585ab03c9f9ae5c0ef230f.mid
# lmd_full/4/4c1a731b52ed812afeb985b2207b0d5e.mid
# lmd_full/4/40f97eee291203f99b1fcfd24aa159ac.mid
# lmd_full/4/40fc0b156af623f86398c2c48ac1f131.mid
# lmd_full/4/4749d1098ebcad2cd724cc86a1656cc7.mid
# lmd_full/4/45391295a039dcec96d5e4eceae208a2.mid
# lmd_full/4/4d54632761fdec16cbf6672bfabde3af.mid
# lmd_full/4/4afa8ef2663e310bd5ae674a340a349c.mid
# lmd_full/4/4e7aee2080c34cd193a9d33d503434f6.mid
# lmd_full/4/4a2b0ee97fd37939387b32cf0446e909.mid
# lmd_full/4/4f565dd9fab9be23c0543c4d731834f9.mid
# lmd_full/4/4ee09cb6134ed253aa5f9763c13a260f.mid
# lmd_full/4/41d4e203855101033450670631c89d07.mid
# lmd_full/4/473cb8e1eb9dc1952885298a1f088a4d.mid
# lmd_full/4/4c92f6d970791075934837335f772c90.mid
# lmd_full/4/4b8d439baa8fb54bd92eefc0cf51c215.mid
# lmd_full/4/404885b9a7992f4f1f14d88629815a46.mid
# lmd_full/4/4664870501e8edd18194e28914f80739.mid
# lmd_full/4/4d30e4639653e85b3d113a81bfd401b1.mid
# lmd_full/4/4f3a4011b9e85aaea82781203cecafca.mid
# lmd_full/4/4896e22b70b7b319aa4632c5bcfe8c3e.mid
# lmd_full/4/4da8419be180173584d6811c52dd0e91.mid
# lmd_full/4/40834bd0ff9ad9f9e575f14c0a3c6079.mid
# lmd_full/4/4b616d25c9c01f95c508cd009a49e7b3.mid
# lmd_full/4/486b2309fc6ba28dbbbac24ec3aab273.mid
# lmd_full/4/497754ee3c61bcc24fe13f223114db84.mid
# lmd_full/4/4243fc46a87e2456dd1b58095ffe23b7.mid
# lmd_full/4/4865b6547c40444bac27b79fe4fa718f.mid
# lmd_full/4/438e06cb11ccde7ade7cf1b47ec770ba.mid
# lmd_full/4/4ce07f5d47da875ea79f0630b327199f.mid
# lmd_full/4/490caadc07c244d88b18628441d35865.mid
# lmd_full/4/4df1612744f9a9cc34ac441725ac2d57.mid
# lmd_full/4/484f38ff9a6980eaa10e0a9e6f70ef1c.mid
# lmd_full/4/4ac986dec74deafbf31d64999590080f.mid
# lmd_full/4/422dda342ee05dcde60f9f8d36d7fed6.mid
# lmd_full/4/4ae3dafcdde4a79d8a2c912abede135b.mid
# lmd_full/4/4324911c5a92ad640c8cd569d4e5875d.mid
# lmd_full/4/46050eae1c4a35cc77ee3b1f9e96d86b.mid
# lmd_full/4/439ab44009bab3683d6e69b3b9a3423a.mid
# lmd_full/4/47f5dc33f8b6b88ea19a206b054c1932.mid
# lmd_full/4/4bf0b2c3c37ebad06a26662d03b7faf6.mid
# lmd_full/4/4fff27d8aa402cb8088740635d2dd370.mid
# lmd_full/4/4673ab60389175b23b4d51acaa7cf3ec.mid
# lmd_full/4/4645eec6d1187fda9c19bf54acb9bafa.mid
# lmd_full/4/496d2bce05766c5ada552c2749c1423b.mid
# lmd_full/4/4b323a13d36e77835b1ca57607e2896c.mid
# lmd_full/4/4ff847e973a57ebd4c19af12b5e27995.mid
# lmd_full/4/44fbc69618afe168a409d0bb089b92fa.mid
# lmd_full/4/481f9a743723a666b611919852119242.mid
# lmd_full/4/4459850c0d61064d4f22d5af7534945e.mid
# lmd_full/4/4aba4eab816ac46ad66c020b22bb9c39.mid
# lmd_full/4/4396dafc56cddba71bc5622b3c4be229.mid
# lmd_full/4/46df58a104fe27391dc56f003fc01ac9.mid
# lmd_full/4/4fd317fb666272852a8ad911e34eb0b6.mid
# lmd_full/4/40388c8856d6cf9f8931af10b09909a4.mid
# lmd_full/4/40aecbbe18f2bae49263106e58f633ef.mid
# lmd_full/4/492ba174e73f87c60c21b272c849b0f3.mid
# lmd_full/4/484d15c6f213319ea0bd5ca36450e58e.mid
# lmd_full/4/4678f6ae8b66e533e04cffccb791c141.mid
# lmd_full/4/4ea9f6cb80970f9623250d4b9d4911da.mid
# lmd_full/4/4562202def2473413615cc301129394b.mid
# lmd_full/4/4d7b6d51227c1d2a1685ff7c479c5bde.mid
# lmd_full/4/4383f23204daf13be020273c1dd26138.mid
# lmd_full/4/45a89cc6dde0db4ad4f5fe06b493a982.mid
# lmd_full/4/43093ef0a68f5ffd18bace938874a8bc.mid
# lmd_full/4/48ae9b5c98260946d65b7cf37c62517e.mid
# lmd_full/4/478fa98d00eb4caaca660900983744d5.mid
# lmd_full/4/48f76c96bc396d421c1ebc1eb54975db.mid
# lmd_full/4/43e37758b611f113fd25da448ffeecbf.mid
# lmd_full/4/4ea07590fd8a5a43d60863bede089634.mid
# lmd_full/4/41bb56fc9eeb9bf90f93da14836bd42c.mid
# lmd_full/4/4b0baf713727f8694839407d0ddc86e3.mid
# lmd_full/4/43fb5caf8b21c9fcf7602c9c663f6a91.mid
# lmd_full/4/443fba80e871ce4d566b938921d08bc6.mid
# lmd_full/4/4225963f9030054db17370c0cac08ed5.mid
# lmd_full/4/4cdd6273939709c0127a47c50e747248.mid
# lmd_full/4/49b020883c65c40e3c861445e1210a44.mid
# lmd_full/4/41bead1c0381f9d97f034caedd94e251.mid
# lmd_full/4/42a2ac05ac3ebcfe04fa2fe9e32330c5.mid
# lmd_full/4/4943e4616ab8cba03840d0235f0e6ad3.mid
# lmd_full/4/431e83ff3f9837643d0ceec8bb14b1f6.mid
# lmd_full/4/42f4ee99a425672ee59e08947b2737e6.mid
# lmd_full/4/403f016c0fcc976a8bb5e58847717c97.mid
# lmd_full/4/43d18c591e18b3b9346de47ddea1e08b.mid
# lmd_full/4/4c4c63600e9eb5f0515d8864c537ca9c.mid
# lmd_full/4/483afbbc7d49c78a7d3cba1de46276d1.mid
# lmd_full/4/447630bdf2e0cd1689b95e556bf95024.mid
# lmd_full/4/43931d0a307dd11bafba213af1739bd0.mid
# lmd_full/4/40b4196f1a232895622ce387672e4d00.mid
# lmd_full/4/452e2561e527d46e75f079e382b0e41d.mid
# lmd_full/4/4e71449158e4aebb0de07d9d65f70bea.mid
# lmd_full/4/4d0c726b4a7f3aef5b1c0fc0590a0a6d.mid
# lmd_full/4/4bcbde72b7f8d409f4a54b082d1c3ccc.mid
# lmd_full/4/4bb7b79a663e755a92b43a3508904066.mid
# lmd_full/4/4507533052c4115a753dbb2b883c6b47.mid
# lmd_full/4/4bb6cac1d32a56aa9f1792982d3cdf7c.mid
# lmd_full/4/41790e0188da9e48c030a2b08091cac9.mid
# lmd_full/4/47bb5d02f6f21ac1970720866a5100b3.mid
# lmd_full/4/4c7a3ccc88dd2e0d46f8c0c625b2fddf.mid
# lmd_full/4/47426e84e957968f477ffb0adb7d622d.mid
# lmd_full/4/40fe36058d9e4446efee4d741875c4f9.mid
# lmd_full/4/42b9a530ae8ed503cafb300ca79250dc.mid
# lmd_full/4/434064f4d4c54c17174449096204438a.mid
# lmd_full/4/442b5523c56439decf750c07485c0d0a.mid
# lmd_full/4/461204aba63a5849c052fb9300b2d1ed.mid
# lmd_full/4/4d4736a03f5ae42a121eef8b357bd5fb.mid
# lmd_full/4/42bb87e65abb7f70e29afc63df55e899.mid
# lmd_full/4/4f2a72ae034ce852c804b6a00cde9cd2.mid
# lmd_full/4/49ed27893e75e04e799e9f95c0c03f64.mid
# lmd_full/4/47a35957ef209189c16e11b8f7ace419.mid
# lmd_full/4/49a2ab01593cf09e4d575a81394ff806.mid
# lmd_full/4/4917b331ef5c2cd7ee4b3a03890489bb.mid
# lmd_full/4/41302f4f2d514a1b69e87a6dddfaaade.mid
# lmd_full/4/403c851f5adcaea456213d7367a3942f.mid
# lmd_full/4/4433cd8d90d35bd519340bf8fb2d4b7f.mid
# lmd_full/4/4c308b951fa9b83335a921e35408a619.mid
# lmd_full/4/4892ce3d2d952e0e598f5818c367ccb1.mid
# lmd_full/4/4dc0a3f2948b7d1f9fee6f9713dad511.mid
# lmd_full/4/4aac6f96e0bd96fc612f88a0af90be5f.mid
# lmd_full/4/43ce630b3777d380c71398328114afd4.mid
# lmd_full/4/4c026de1af9c7559c319dc287efd9d0e.mid
# lmd_full/4/45d83ca8c34cf65a723b155cf889efc7.mid
# lmd_full/4/413c055c73773782ac3251bd91192051.mid
# lmd_full/4/421334b58ee28affcf7fff596719e83e.mid
# lmd_full/4/4a19c0837793fd2073444d31771a2064.mid
# lmd_full/4/4381e39736b329cebbd4ff375f6b71b0.mid
# lmd_full/4/40a18232c3b6e21c22e07c45e6cccd1e.mid
# lmd_full/4/491c491a0cbee7b1b8a1ece337c153ac.mid
# lmd_full/4/492bf9c4563eda280f4d6771e7a3c04e.mid
# lmd_full/4/465721507a78ab8974a53272b100ce6d.mid
# lmd_full/4/495eab9e5f422605be3a4d3b7983ea7b.mid
# lmd_full/4/4dcfe30200d9514e391a48431d6c492f.mid
# lmd_full/4/48d60dd5077934b477d958299472ecc4.mid
# lmd_full/4/44d8fb67df84ae1adba8bd49a9fe1936.mid
# lmd_full/4/4f9240f77c5011fc91851ec568ee5d70.mid
# lmd_full/4/4d880ad21827e8216dfd13384529371c.mid
# lmd_full/4/4871b25cbdbc8529de3154256e78a0e5.mid
# lmd_full/4/4fb0ab0fb6d05257b137ec4d2a62166b.mid
# lmd_full/4/4edce799e83db4300f200524676c7751.mid
# lmd_full/4/4e1034a9be190bc28457f01aaaf01a9f.mid
# lmd_full/4/4b80d831e0a597373c794d57ec456d87.mid
# lmd_full/4/4db8c91564088483cb22094294e752f1.mid
# lmd_full/4/431a7c8b372958f3f7cb7f895e5ad448.mid
# lmd_full/4/45ea9da06ac55bd5452b2a76d1e2f7bd.mid
# lmd_full/4/4d04481ee1bb8f5e23d087e70844b374.mid
# lmd_full/4/45920614bd3142da383f8b6a583b9ebd.mid
# lmd_full/4/4cfa025b630863cbf334e200d2bacda6.mid
# lmd_full/4/47d5437236a2aa3c36b2678018b8f39e.mid
# lmd_full/4/45144c5a39a34f5a93fd0a6a7e633a9a.mid
# lmd_full/4/489381b6a644651a4b4b313c2f24bdce.mid
# lmd_full/4/44e30508e7fc0df3bc71106fc62141ce.mid
# lmd_full/4/4b66462e9d304ff6a9aa0b104dfc1ec8.mid
# lmd_full/4/46f9fa06f2f3b68da8f79f701d48cd4b.mid
# lmd_full/4/471968bdd8e2999f36f9f07d14f2de9b.mid
# lmd_full/4/4ceddee8aa4d7814ca752324e62d0e5e.mid
# lmd_full/4/486ef94eaf69af2dd2dfe3c7181386af.mid
# lmd_full/4/4ffba08652b4ebb3bc66814043ece1de.mid
# lmd_full/4/42cda74d855ea54e46e53e289228153c.mid
# lmd_full/4/4567f6342e9fb1ecca5fe2cb02c980bf.mid
# lmd_full/4/4a24958f36b089c31a5727bdf06cec06.mid
# lmd_full/4/470b8db85759b11106934a2fa756aea0.mid
# lmd_full/4/4d0059d49d78a19ed77fbeb6eafc7f66.mid
# lmd_full/4/42dde2a4b34614f885d722e4ba072b4a.mid
# lmd_full/4/4e42524ccd58aa56da02363543b5a0ce.mid
# lmd_full/4/479cbebb7e9914ead52ced8828173575.mid
# lmd_full/4/4a06e4ed9cca55c32566d545b0f1236d.mid
# lmd_full/4/4ab13a050407c8cf6e09f7607e28ad02.mid
# lmd_full/4/45396d58bfc643742722de29488d65fd.mid
# lmd_full/4/483236aadb8ae2cb2e9d8b69ab35c9bf.mid
# lmd_full/4/49de4fb9102682e4f84ca3fa189ef915.mid
# lmd_full/4/4ab5c7a4461dc56d04e185b76a4f8a51.mid
# lmd_full/4/445b557bf7897987d0fb92a30c325240.mid
# lmd_full/4/4cc3b14cb6dc045bebd8fa11d038fb53.mid
# lmd_full/4/4f37d164a2d56eea52ac43792a0c6cf5.mid
# lmd_full/4/463cc72e1390ffa9446cb2719388de8a.mid
# lmd_full/4/4932d3796af68bf270eeee2ab89157fa.mid
# lmd_full/4/4eec27a62b06b440079708ebdd3374a8.mid
# lmd_full/4/47953bd07c15ab4609d4033b8073bb82.mid
# lmd_full/4/41f6870cf1ec019b75b477a0dade36f9.mid
# lmd_full/4/4ab4844b71a5c17108f7111989b80274.mid
# lmd_full/4/45eab0c08636ecc704a5b53e4d6b6ad8.mid
# lmd_full/4/4f16300ac529ccf72d9fff8d5fca6480.mid
# lmd_full/4/4b184a40213a190bd9de358ab5632639.mid
# lmd_full/4/4effe9088f03714efc28d774e0fa44a6.mid
# lmd_full/4/4c221a6783c5cd7336f201cb994aef0d.mid
# lmd_full/4/4e5b9f716c5c1fdd86e0b360889d03cb.mid
# lmd_full/4/4def1f3e87022fdbce2061b51eb33709.mid
# lmd_full/4/4cb959911398965df0134b1443e72f4a.mid
# lmd_full/4/40215f59cee17f324de38d10a24ef5c1.mid
# lmd_full/4/4201e8f692d2099288ed750bb78a398c.mid
# lmd_full/4/44371bfe489cd6230786280bd2b55cc1.mid
# lmd_full/4/493e7adf4a2176fb00ef305b2807820d.mid
# lmd_full/4/467ca6ac39aafbd489a5021ed94132cf.mid
# lmd_full/4/44741385cf02946eae6b3bec5e52164d.mid
# lmd_full/4/477ec08180d35603c5fb41e650b31f8f.mid
# lmd_full/4/4cd07d39c89de0f2a3c7b2920a0e0010.mid
# lmd_full/4/4aad449b96dd30a49b7ed59e1c255ee4.mid
# lmd_full/4/4ac48a2417bb834ff8fc68f7ac64ea59.mid
# lmd_full/4/494bff06f418eb80e67e3170db86bd81.mid
# lmd_full/4/4b18792cdafac7b421462d1173920bfd.mid
# lmd_full/4/4c2eefe1a87b85ca00fcd67e5c0bef72.mid
# lmd_full/4/4e91aa9d3beac5754fe2466682e314c5.mid
# lmd_full/4/41039529630a3e1fc81cd0497a1546a4.mid
# lmd_full/4/479e10016f3e0d10dad36c650f7bf750.mid
# lmd_full/4/4cbdbf63a53b92b0e6059268b4475ad1.mid
# lmd_full/4/4d0b016ded750907699ca1f9ff91fc96.mid
# lmd_full/4/4ee0783a93e0e258c529b92ef532855a.mid
# lmd_full/4/48fad82ec5ed91860da762b086029894.mid
# lmd_full/4/4a3ad0d76d45baf9e02bf0ae32128bc7.mid
# lmd_full/4/460bfd0095b639ffcb8159e0ee63e5a8.mid
# lmd_full/4/42712bfb32e51409245294a2e979a737.mid
# lmd_full/4/4d5e0f62aa8d8f1f382d12195892ec97.mid
# lmd_full/4/438f662d3019ed41ff96a8b00612ffaa.mid
# lmd_full/4/4611a742de384e018dfeb85a1101abc2.mid
# lmd_full/4/49f347dd02e928a15b79ed73aa8ce92b.mid
# lmd_full/4/473a2f1ac482ef976146d61b930fbd46.mid
# lmd_full/4/483fecdd2ec9d50eb78f175c617ab9ee.mid
# lmd_full/4/434cd5844f8cd64465fe4798b5f3c543.mid
# lmd_full/4/4b78b046d04ee3057e98a45b496ee7f8.mid
# lmd_full/4/4fb3594348e6f9d6314a5e383c1776b2.mid
# lmd_full/4/4f0ea7ce148d4673ecc06165bf542807.mid
# lmd_full/4/4ab6d5fb287ee403fbcd38c073f744e3.mid
# lmd_full/4/435cb40f807c3b0c79e0a1b25a085175.mid
# lmd_full/4/4fe7814a383c75f39a7ec737ff45f259.mid
# lmd_full/4/465ba94b52f78376e826517990e1a3bb.mid
# lmd_full/4/4b9ec7d6c7a9f72475f8a01b04122bd8.mid
# lmd_full/4/4476068edac3c215ae00a9add25bc497.mid
# lmd_full/4/42f4849b91705f2cbff40268000fe511.mid
# lmd_full/4/42cc3b84397f63d0df197119cd6b84fb.mid
# lmd_full/4/418d8729f6b6782d9bbde24b6abd58ae.mid
# lmd_full/4/4476f868ca4cb56ff612c55b9344a5b1.mid
# lmd_full/4/4f8e0ae91c60a398d95411df4b9919ee.mid
# lmd_full/4/43883663dcc7c00da52d1fbfca923ec1.mid
# lmd_full/4/4c1decb03ebb56423e4e2fc8933e5067.mid
# lmd_full/4/4be724538bc3e321277e958544ee3009.mid
# lmd_full/4/48a06f679fe7381b0adbdac62e131e5d.mid
# lmd_full/4/47fe95996ed22d17e37107cb96926b76.mid
# lmd_full/4/49751ac534c068f607f7921c8064c6c3.mid
# lmd_full/4/49e6774bc37d873a0a875ed4068ffb49.mid
# lmd_full/4/432ee01ab32d3daa1792a4a21d7d58a4.mid
# lmd_full/4/4fc0b467b7397bcdaff20bcd608faec0.mid
# lmd_full/4/4890e973a466be56c786268a814a9f39.mid
# lmd_full/4/468dd0cb76ba65cf5b3c572b5d4a9ea1.mid
# lmd_full/4/473524e9bd9ece39c0eaef1085b46af0.mid
# lmd_full/4/4ff7273bdefc7918c62e1ba72f61c37b.mid
# lmd_full/4/49edbe39fbd8650a6ecf1b3b3003bd7b.mid
# lmd_full/4/4094b31eb460d22d39559066bd95dcbd.mid
# lmd_full/4/40a42dde662ea49e48092feaa3a88882.mid
# lmd_full/4/49f7bc69cf868857b49d494b21f70d76.mid
# lmd_full/4/44760b067052a933aaa318b856c4c4c5.mid
# lmd_full/4/4a4befb10fe6215c7439b9649af615fa.mid
# lmd_full/4/4774ec03144a790943c37449f1868b0e.mid
# lmd_full/4/4c66d20ab43a71216872c21c0c335841.mid
# lmd_full/4/4aec9129d6f3df0f112032ee69d9fb0d.mid
# lmd_full/4/4679ccdafb3cbd0538ab317f751297f4.mid
# lmd_full/4/4062ca7e3d52f7ed09ba2690af34564d.mid
# lmd_full/4/4a7b696c7d9f8baa2510e0e21e4ae7e1.mid
# lmd_full/4/4755d8175bf61113617a7d479519a697.mid
# lmd_full/4/4def36d3bf6d2cd805ff4dd5b0d42c3c.mid
# lmd_full/4/466dd8daffeab50d597d7e0193f51257.mid
# lmd_full/4/4d7e758bac89e1fa224e1acf175df63b.mid
# lmd_full/4/4b4471f548f2c3391c77436082ac9fdd.mid
# lmd_full/4/484a02b8b8c5f620559094e100ae24d7.mid
# lmd_full/4/4ff0826541842fbd5b33840aa31ec122.mid
# lmd_full/4/4912fb23f856aa4a6d0c7df63805d31b.mid
# lmd_full/4/437d8ba5048800f2327afd9c4e71ed17.mid
# lmd_full/4/44fb6ace63561b33a055872700d7f3d4.mid
# lmd_full/4/4be949a409db837bd1b8c10a11f5ed71.mid
# lmd_full/4/4cd7238e88d38b95dd38ecec16fa65a5.mid
# lmd_full/4/45df291bba55b94443c1d94c4fb6da97.mid
# lmd_full/4/49fa6a54d7d1f449c46422935e9f24df.mid
# lmd_full/4/41091be72960762d22988f53b00f4208.mid
# lmd_full/4/445a10ea18451bdc79d9e0af8e3b0582.mid
# lmd_full/4/4ad20d83d4040b12c4e1c3c3d815b523.mid
# lmd_full/4/4eca24a6ceb72077dc4a88c4296e1f97.mid
# lmd_full/4/47fe60c845e005260a36626c21525dbd.mid
# lmd_full/4/4355a6332bc7bd4d374198d75f156ecf.mid
# lmd_full/4/439893b79806000953f1ab0441593677.mid
# lmd_full/4/4b578b2bc8d8a2a2aa7e3f08713938d6.mid
# lmd_full/4/4d7ac0872cbf7634a6b7a8cd2e8a6064.mid
# lmd_full/4/473682a60d4431c7add47e2bbe2112ca.mid
# lmd_full/4/4b0f6de9ab48698a0f4d11a54989d101.mid
# lmd_full/4/43309179a5428d27f312e49f42e1f54d.mid
# lmd_full/4/457c78284f61c5500f12452ddda864be.mid
# lmd_full/4/435fb5a6d376e258b480e4919a0b23b5.mid
# lmd_full/4/4974b292d6fe58cca58234cd58d8fad9.mid
# lmd_full/4/4bd88de5c104d22e411f080b8747237c.mid
# lmd_full/4/4539b84af843fe43deb3b334fdbd42f8.mid
# lmd_full/4/44ac822dc34250e9d9c9992623c5e7aa.mid
# lmd_full/4/42f4a58d8980fd111c4e58fea4080ef8.mid
# lmd_full/4/4d646ef558f03434b9f2476642aa9820.mid
# lmd_full/4/4c9c7acc8c7311114089be533d020539.mid
# lmd_full/4/43b143fce871f1e718eb0efb3175bc5a.mid
# lmd_full/4/43e3cf897b86581e44e0b41d56fca5d9.mid
# lmd_full/4/432cbdd2ba6d9e084c34a482eae8d72a.mid
# lmd_full/4/47468848aa0c931bcb410a620c75768c.mid
# lmd_full/4/44cfa385ca2394e3f438b3ab61e641c6.mid
# lmd_full/4/46d30f800546750b333071539f3a8a0a.mid
# lmd_full/4/46eef125da9f95a96df927027e1991e4.mid
# lmd_full/4/4e314543b68eaf7a65c0a6ef0d3316b4.mid
# lmd_full/4/41b5b4ce6f4e84581d1479052195f451.mid
# lmd_full/4/433d41c53e8af1ae6a3d7d6c4ee37a61.mid
# lmd_full/4/48c92a6ddf69058e3f502da7d7e9e283.mid
# lmd_full/4/4bfbcd90f8e8bd22f5438fe1f212aaa3.mid
# lmd_full/4/4f2faed671a417f5510a094815d53daa.mid
# lmd_full/4/4923146cee7bd95f0a0b276b3b28b165.mid
# lmd_full/4/46d8bea2b3ba4b0c5324d270348c61f1.mid
# lmd_full/4/430310dcd9dbad9d5202b2c4042c0dd3.mid
# lmd_full/4/48392101999af82b427a53bc7d60872b.mid
# lmd_full/4/4eacf04552b5436077ce40b3a6b7d5e3.mid
# lmd_full/4/4d9a1e2b73d2801286cf038eedd1d144.mid
# lmd_full/4/45b2322156488f3b77b6cae8c9c5cee3.mid
# lmd_full/4/42742e6e6ab9dada1c76da39c11b7dee.mid
# lmd_full/4/477125009c307b7841f76bb52139f1d3.mid
# lmd_full/4/498b501947490c2a1df840047deae4dd.mid
# lmd_full/4/4d2842ad075f08b0039e62fdca60af21.mid
# lmd_full/4/4c135449704b2caba0f68d2929dcaf09.mid
# lmd_full/4/4ea657ec25e60e4ce3d3a396aad1aa23.mid
# lmd_full/4/481b7481d5ef810d57c257e03635b015.mid
# lmd_full/4/4d6f98741f32fec535eef648ca4a9328.mid
# lmd_full/4/4596e9cd3efee97b995c6915e962df73.mid
# lmd_full/4/4bd3a73e928251a3661d9eaad77cd571.mid
# lmd_full/4/42dc388d32edc012aad097d3667deb3e.mid
# lmd_full/4/44cb917f2ef9f0ee96d07aad09ed9117.mid
# lmd_full/4/43e9979cf81ecdebf583a87851c7f46a.mid
# lmd_full/4/467ee7cfcb3d4dc595a6c6a336566f4d.mid
# lmd_full/4/42ab80d4abb88ed2cd5a88ed798b1261.mid
# lmd_full/4/48e5602a00f175df2f30100e4d881bab.mid
# lmd_full/4/4cb75aa5299bd9a292752accbe973cba.mid
# lmd_full/4/4b8891b5ad6115d1f3de7c8755a1f918.mid
# lmd_full/4/4a3f8b9f4607f82a2b7a2c6f7dc7c467.mid
# lmd_full/4/44681e91da257f274bbd12febfeeaf4c.mid
# lmd_full/4/424dab7f985a46d79bb235f36495f1c2.mid
# lmd_full/4/40629d54c6a54461abca0b6f4057cc1c.mid
# lmd_full/4/4ab912e9fed8f635461a0bc78ff93da2.mid
# lmd_full/4/41ec5248f5bae6b1ae7206c03c2d1a9f.mid
# lmd_full/4/4a718e5ab35cecea15da7f1a2ad768ad.mid
# lmd_full/4/493afacf6e2a941a3e5f955b3a8f2d1e.mid
# lmd_full/4/4b5202638f9cc60e25583a6d511b3d71.mid
# lmd_full/4/46682cfab8435894b5d49ee4dbd2610d.mid
# lmd_full/4/43ec1dff44f80e4e92fd8d3676d6052a.mid
# lmd_full/4/4baecb22b0ad891ac81a2ff9fa9036ab.mid
# lmd_full/4/450e5cde93b47c600739d08fcde9757e.mid
# lmd_full/4/42d20dc115375a43016358a56dd714d3.mid
# lmd_full/4/4f2d3fa4bb395171167c28f3cccd8cca.mid
# lmd_full/4/4ad56fd808d4f9b88aa7e4d496328ccf.mid
# lmd_full/4/4cfccf23847bee76b965d1263dedd465.mid
# lmd_full/4/47d13fb5f758067e1004df0aa0b4782c.mid
# lmd_full/4/48408608116c6a12e50f970876b2f8d4.mid
# lmd_full/4/41f88e739f559b87e794a08698bbcb5e.mid
# lmd_full/4/4aa16234036bbac845d40f83fb4f5613.mid
# lmd_full/4/4a0107e0ae373f8aa93ea3d9150cc66a.mid
# lmd_full/4/49afb6589973ea29c354fb5d3a57bf46.mid
# lmd_full/4/4d0ff75a12ba3173702a646cabbd2f4d.mid
# lmd_full/4/4c0bf2a0e76be08b3cb33805459333d3.mid
# lmd_full/4/4fada02ad9348c46944aeeeb63573d1e.mid
# lmd_full/4/47a9b4ba70dbbe5181d2faf78784c44a.mid
# lmd_full/4/4f5baab2fc93eef6aa20ac3d54c092b6.mid
# lmd_full/4/43501d28d77d9bd1fa507402d9eb8eb8.mid
# lmd_full/4/46e860a8f910784e3121c8e8cbde7464.mid
# lmd_full/4/4ffa3ad60c9bb1eaa2182e162f51fc7d.mid
# lmd_full/4/449523bc9493c1eb0869458f48939ca0.mid
# lmd_full/4/4314b4577c848502565d6b3902eedaf8.mid
# lmd_full/4/423a973b0009b5a370fd553c43d1e159.mid
# lmd_full/4/404d1185193c96336db997cd0a80acaf.mid
# lmd_full/4/48772816bdcac1f1e8747d32191544fd.mid
# lmd_full/4/48d93c1e0ffab5c5b3852a8a85f27037.mid
# lmd_full/4/4a63b02361bc613f4c9cd8d9ba820ba8.mid
# lmd_full/4/4bd64928a586a10cdff73c7b91b7d232.mid
# lmd_full/4/4e2ac1237ee7067cb76f9488f404d950.mid
# lmd_full/4/41d31a18bf51efa510d80c5242784044.mid
# lmd_full/4/4766c71390da4512ca5830c08cf7473f.mid
# lmd_full/4/493138220f46876568c23bd2cf500aec.mid
# lmd_full/4/433b697f960ec6cd7a32619eae687728.mid
# lmd_full/4/413e988d8dc24c443b6ac40b1b297019.mid
# lmd_full/4/4f2732850e8aa2241342a0b90fb1f7f5.mid
# lmd_full/4/4051d749e52cc5264d7a3efe997e25e2.mid
# lmd_full/4/4a60f172c28bf1546eb61bf214c8f71f.mid
# lmd_full/4/4de216ae872d8620b60b24fc2ceb215d.mid
# lmd_full/4/4ea3c66d8771d568f7849a0aa7a3d7ad.mid
# lmd_full/4/49805fe166e0dfb304a08cba25ffefff.mid
# lmd_full/4/44076f0250ee9b7a43536cd505488c99.mid
# lmd_full/4/45e0cff7e52cf31b3caa11360b11699c.mid
# lmd_full/4/4eba86ecc9063b3cc4c0200cd69c6b22.mid
# lmd_full/4/48442768c298463682704d482d3d7817.mid
# lmd_full/4/4ec093bdd86c9427ee65bafd4146faa7.mid
# lmd_full/4/4cff76c7031252b8cafa50dc58e57bae.mid
# lmd_full/4/4304568168d6dadcecd0520fe5c4f5c6.mid
# lmd_full/4/47ba202065ffda8b3104208de03c019f.mid
# lmd_full/4/413d72cf128840d275f6fdf85c0baad6.mid
# lmd_full/4/446493e93446cc71af80f898e9d71f7d.mid
# lmd_full/4/42b46a66e26d1a357891ac1a64450b05.mid
# lmd_full/4/483b9799b15a4463cc5e5c7624a50d25.mid
# lmd_full/4/4d78d7c26582567027c61cb568cd8647.mid
# lmd_full/4/4ab2794abc4b83ef7f1a3d22dfb6ecd2.mid
# lmd_full/4/4cac90a3c9ca46275dbbf947106db470.mid
# lmd_full/4/4875be037eddad04086ee287782587c8.mid
# lmd_full/4/4a9c2fa20dd29b6be021cbb4944ceff5.mid
# lmd_full/4/463c4e64e08dc0b347e58dd23dceec1f.mid
# lmd_full/4/429aa9b62900fb6815fbeaa0b3afd3f5.mid
# lmd_full/4/4d44f41775f6faf1dd7cf677e9657a44.mid
# lmd_full/4/4a54d5a14fb67e76233634c87f16411f.mid
# lmd_full/4/4116cdf9c107c4e9170b58290898093d.mid
# lmd_full/4/4f8940b41a30b6c5a2ba28ac99c57235.mid
# lmd_full/4/4daf4ce84fe3ddc7846ab3b11b6915da.mid
# lmd_full/4/4bba7213107b8e7f09402f1d5cefa729.mid
# lmd_full/4/48537f1713c64e0b970c22da13b79fa8.mid
# lmd_full/4/466937845d4c5e200a9aae1e85701c2f.mid
# lmd_full/4/46ae8cfdecdc261d1a5426f87fc57307.mid
# lmd_full/4/482bbf3299db522983e342fe538d94bc.mid
# lmd_full/4/4d194a2489eabc7a75c009c5a456a261.mid
# lmd_full/4/4add6552d430d8664ba1505d5c715dba.mid
# lmd_full/4/4b94c9bc68a95d7f2f1ce5c4bf8de946.mid
# lmd_full/4/4691f221e0d9b542d4cad7384894acff.mid
# lmd_full/4/441b6ba32a6ebc952f71e143bd780a70.mid
# lmd_full/4/48e4ac688716f35771539e70da798592.mid
# lmd_full/4/4cd03c7b648e6944623a32061144fe3a.mid
# lmd_full/4/40ccc7861aeba87403a55b48ed4fa351.mid
# lmd_full/4/498240cceefd65bc20f87a94cc3ba6f0.mid
# lmd_full/4/41e34a3c5082c80bfba81852b63948f4.mid
# lmd_full/4/46f7dd465a3dfb21b9fcab5ace0133b6.mid
# lmd_full/4/460fa461dd550c7a31fc25f84b7ce81e.mid
# lmd_full/4/4f0d7fee1be8caa609972c9e95a331e2.mid
# lmd_full/4/45b2adcd3e45ac9da44c90dc7fbcbd6f.mid
# lmd_full/4/4f15e0d009969f5b8d12d28a36a178c1.mid
# lmd_full/4/4a28c2d4804439db7d913e49adadb282.mid
# lmd_full/4/4ba7ff6a670af2c9459d04fab646586f.mid
# lmd_full/4/4f50835f36624e058f2cfc0cc0b6e863.mid
# lmd_full/4/43644b54c646e6c479f3a29cc63ccb74.mid
# lmd_full/4/44c0b50d50f5009c076e1159f16d4756.mid
# lmd_full/4/454ce546a02c6822f948a12d45086679.mid
# lmd_full/4/428ab90727c4e158cc8ccdb627939316.mid
# lmd_full/4/43e7cecc7978300316fade71c057e2d8.mid
# lmd_full/4/45d7026f179914d2ebb96f18a2a4698c.mid
# lmd_full/4/44c12da8e482ae46548e8f274bb76860.mid
# lmd_full/4/471309a3850776c03edfe9ebf9675934.mid
# lmd_full/4/4e1e30176c47a90ca296a738a1f33a63.mid
# lmd_full/4/4d46dab762878d3f860d7c1e7fc22b95.mid
# lmd_full/4/4d4b8eaa15e6ef2c7a0acfb6353dc8cb.mid
# lmd_full/4/46610dfd77ce28bc9fdd494e47fdc4c9.mid
# lmd_full/4/42d7f0e79c4a6a4aee6e279e92370af3.mid
# lmd_full/4/48a7fea7ef75124206f12714e85f6095.mid
# lmd_full/4/40d13020489fd8c44f597fb8937fc53e.mid
# lmd_full/4/4b63840667a8e038417ffa3a59e5269a.mid
# lmd_full/4/43b8270f62fbc93d5872f9afc9516941.mid
# lmd_full/4/43eaea0eae12cc3d594e7915ca4eadea.mid
# lmd_full/4/440988e815fb2684655167d473fad0af.mid
# lmd_full/4/41acbc5e9279a9fa8e3692bd62eb2d17.mid
# lmd_full/4/40cb26293f12822e86c031b64de2dc48.mid
# lmd_full/4/4298af854d599f55d59fe9e87d3046d6.mid
# lmd_full/4/4c717f2222078ee74711ad8cad779429.mid
# lmd_full/4/4f8a583477ee3d87fe329ee70565f28d.mid
# lmd_full/4/497f832976b5d889cc2712453a40d2ae.mid
# lmd_full/4/4cdb62cf1f7a0ba74c281897d7a4351b.mid
# lmd_full/4/40f079e1a7a409d1792ef349d29736d1.mid
# lmd_full/4/4f01fbdcbe370575b529bfc4cdc5dbc4.mid
# lmd_full/4/461b6d223194e22267f0c12ca7f40716.mid
# lmd_full/4/45e8bde06e13905465a3062b5a4d0ca2.mid
# lmd_full/4/492b243e0228f0869e526fe2c54307d2.mid
# lmd_full/4/4cb81511c642bc357578a878b09f48f1.mid
# lmd_full/4/4450d53e6b1d60c7428a30f6b20b5e81.mid
# lmd_full/4/49d72791dedf16ba15e171b8d03a4705.mid
# lmd_full/4/48c87663f948488e5ab20b423ce0b247.mid
# lmd_full/4/4618d5285fbaefb72fb66c3b83cf81a3.mid
# lmd_full/4/4e9253687e175bde697f568385b1c9b2.mid
# lmd_full/4/4a975594926ecf4c75e3c62f9bbba44d.mid
# lmd_full/4/41ae4d716f4e18b04c2c0a9b7984b757.mid
# lmd_full/4/4d8dbc586b1d6414a268a2d6beffcd49.mid
# lmd_full/4/40c9e1e6c34654c196fcd90fa52510d5.mid
# lmd_full/4/41e8002e0f85c6e9ea5e3bb78c78d863.mid
# lmd_full/4/49108d292901d408b4a88565d3d80b4a.mid
# lmd_full/4/4f5a12b4cd0702b085bf016bf5daea21.mid
# lmd_full/4/4c5a439e556b5eee078cb54575367101.mid
# lmd_full/4/41aac3df6d4348a90964781d3ef0292a.mid
# lmd_full/4/497667810bce752506fb0f162f48adcf.mid
# lmd_full/4/48bf7c2ce93f22df58c4f9eaf6be1e97.mid
# lmd_full/4/456e55924d00075ce6f4e0eef97b027f.mid
# lmd_full/4/4d8f36e75346cb76acc78c8cb8433f30.mid
# lmd_full/4/45415c696055bc4be7f5cadb39c6f34e.mid
# lmd_full/4/4a5ee567052b03acc653a5ba03d04d18.mid
# lmd_full/4/480e14ac1d7cea576510fe5de80bcfe3.mid
# lmd_full/4/49359ceee12aa9d56a4359745df50fc5.mid
# lmd_full/4/4deda60b79e5937c542978b18df49af1.mid
# lmd_full/4/4f86ee737f4d96abe89a0b929221a284.mid
# lmd_full/4/40459d8e29a469c833baa11931ee15be.mid
# lmd_full/4/46639ae9d5524d6bc137af1554d6445c.mid
# lmd_full/4/40818e6b499aaee0602b9db45be80950.mid
# lmd_full/4/4355a257cf891f8a736c6051bf9fe0ec.mid
# lmd_full/4/42f6b1f5ec19a06a9c35075105e0ec75.mid
# lmd_full/4/427d9036f8a3720435c546963fc4248b.mid
# lmd_full/4/4d27f2fcbad39bed20a0520d3a8ea699.mid
# lmd_full/4/477026ce42942600f28b277ea9aa80ca.mid
# lmd_full/4/4ba6995cc774fb05ece7e024510bc398.mid
# lmd_full/4/47260b236c357f4007e1a987ba05ce4a.mid
# lmd_full/4/4efd6012268bdc8db6a0b9f97baa8cc0.mid
# lmd_full/4/4ca7fe58809a4b377a07ed0490d3933c.mid
# lmd_full/4/4f49bcde0c272fa301b2a79e916d7271.mid
# lmd_full/4/44a01833c7ab37da0ff694fa5d3ca89d.mid
# lmd_full/4/428b42a15ce45e34fa866a28fb274112.mid
# lmd_full/4/41a6a51283d021f669950390cf1e77ff.mid
# lmd_full/4/456416b895c1210952c35697e6aea032.mid
# lmd_full/4/429575983709a18506c85165cfc94ae0.mid
# lmd_full/4/4619e706d42f0e3049151140ebd582f7.mid
# lmd_full/4/441f6cdfce1f7e6f3b7734b7db5311d1.mid
# lmd_full/4/4396a39d2fc9481553b00a333fe42fe5.mid
# lmd_full/4/43dbd1415f76ca0c9cddc4033b21ce51.mid
# lmd_full/4/45d7614f9179381fd1e5c9e6b875f008.mid
# lmd_full/4/405b1328015d433ef65b80544c5a8665.mid
# lmd_full/4/49982a54d3ed85043f5f8fe59348a382.mid
# lmd_full/4/45e88653620b23bd709fb4c0b44bb6ac.mid
# lmd_full/4/4de10f82b364e5186f97e48bdc796516.mid
# lmd_full/4/4d8c29d301b7609f0dcdaffb5767348c.mid
# lmd_full/4/45e45cf33161a09b7540096fc9c79596.mid
# lmd_full/4/4f4f969f264634419f090d8c791c85bf.mid
# lmd_full/4/47c7f4544a59e66e00f9e593332c432b.mid
# lmd_full/4/4989bb0f99855bd39f8a5d9ef1866de9.mid
# lmd_full/4/442e2839b7abbf316d132f24af1522b0.mid
# lmd_full/4/419575710b79b427dfa5378460b9ebf1.mid
# lmd_full/4/4333f83d78a3673a24ea88fdd5bc9b39.mid
# lmd_full/4/4ec33f516308d688d8e58ef4a02ed89a.mid
# lmd_full/4/4e2c0cd0a2a7e6bcfe2ced586e7a1db6.mid
# lmd_full/4/479cfeaba4c876c3269ca0f3ed4c4ac6.mid
# lmd_full/4/456f507bcee2ee39b820f825a213f752.mid
# lmd_full/4/4b782481c193903eaf55e6c576b40074.mid
# lmd_full/4/415e4efd44e8784c0b8e83372ed2faf9.mid
# lmd_full/4/4d257d5945bb1d7c19fc6ea06e37cd11.mid
# lmd_full/4/4fe9e8549f31253c6e9b4449ee8827aa.mid
# lmd_full/4/4ce2669b217e4fc149fc5ea69b7238fc.mid
# lmd_full/4/4e0b5f96a9f371ced3760a44c65377c9.mid
# lmd_full/4/4df975628d36978980d000668fbb1855.mid
# lmd_full/4/4e1d5e7f526d2d4dfd038c127b4ce68d.mid
# lmd_full/4/4526b47e3627e0a7a31572062defa3be.mid
# lmd_full/4/490c7a2d37e422a86c01025358da286a.mid
# lmd_full/4/4c091701c2596f601b4e7c25d4f12096.mid
# lmd_full/4/404cada149ef8953d1069fafc89a251d.mid
# lmd_full/4/456f82b433a8301790c924a43bb79181.mid
# lmd_full/4/48f5dd6110baca87a169d7ef29afce43.mid
# lmd_full/4/4b9b6892c8070451dd81d7f7aa1e7b45.mid
# lmd_full/4/4afd42248fec6aac8b26bd4d5bf6e6c6.mid
# lmd_full/4/41d74611fddb4427ef4f489672b18cd8.mid
# lmd_full/4/422031bcab9206aded3ce7cfa7de1c2c.mid
# lmd_full/4/420b0a277b301b9b59b0eef632ba80a0.mid
# lmd_full/4/4c71edd7a328cf34432c4abbaa4be046.mid
# lmd_full/4/452a7e7f7d453430046889141c7af997.mid
# lmd_full/4/48abc24302f1ea6a5a50a9929157fe8b.mid
# lmd_full/4/4738a81cc846c3bce95a1f9a9e00f4fa.mid
# lmd_full/4/4d64f19a5dc41947c9d29174cd212c88.mid
# lmd_full/4/40bbe87749526bd20322a739b50bb838.mid
# lmd_full/4/41936262f981c8f4b2259f2224672856.mid
# lmd_full/4/43126979826c841a6e4f453827c0f1f4.mid
# lmd_full/4/4fedc568b4ee09ddd79cb5d7a9bf3e5f.mid
# lmd_full/4/49a20d68d7275d7d4a9502e49ff53076.mid
# lmd_full/4/48ef04af473cac1c2da961ee6e40bd9b.mid
# lmd_full/4/4f2b675996ab83dc2426383d61e77bea.mid
# lmd_full/4/4b2c7f79f0462a429f6ec94d59e2ac42.mid
# lmd_full/4/40de8d614e0d3c17b7787ce642b40af8.mid
# lmd_full/4/46fe23a77fd020e772d24eb3f032bbe6.mid
# lmd_full/4/487977d1947c31f68d476dacc0ccd4f2.mid
# lmd_full/4/4c47620b7cf96a68289c1cd972cef20b.mid
# lmd_full/4/4fc52ae15e1891546dedb473aa49d51b.mid
# lmd_full/4/4173befdf684bb74dca5690217022a6f.mid
# lmd_full/4/48da38acc71af87c51584d9f576be5dc.mid
# lmd_full/4/43dcc346a378f2960fb076d4d3b62860.mid
# lmd_full/4/4ac862959dec76251cd65b8ee26f8d53.mid
# lmd_full/4/4601445be3a580baec3fdece4b44a82a.mid
# lmd_full/4/49e84df28777b4a1ca7a304c46a5186a.mid
# lmd_full/4/4e6469b6456ccb1c01384559beb87368.mid
# lmd_full/4/4a764880fbbe1f30125beace3153c7c0.mid
# lmd_full/4/417a5cdcea68e03a188163a977bd26d3.mid
# lmd_full/4/4e5e9b1e0b89a598f5bcb510d7e76990.mid
# lmd_full/4/46498df487eb20c5e742bec37e910a93.mid
# lmd_full/4/4380df8a0a24fcbd8202cefe377448b7.mid
# lmd_full/4/484239bb33f752a0e9aeede563e87755.mid
# lmd_full/4/41b2e668966c253ac785bc6dcc66a127.mid
# lmd_full/4/4eeb95099b63fbfe238840e4085a6b3f.mid
# lmd_full/4/47dd6121a8889ca4783c5fa1b60980f7.mid
# lmd_full/4/458052f7aa51aadfce2531cd75fb3e73.mid
# lmd_full/4/4b94ff697be5ac29dd4af3371b5f2384.mid
# lmd_full/4/4c82ab250554a2f7d490a34f005ac66a.mid
# lmd_full/4/46f21a52379513860d65133b0803156d.mid
# lmd_full/4/4122c9d84c1d871defe766a2fcd0ae23.mid
# lmd_full/4/4ee9ee0265addcdcc21fbdd9aa114097.mid
# lmd_full/4/4e032bfc9e9476bfaf209abbd9684fac.mid
# lmd_full/4/4b2e332de6706318f31bac5e2b370f10.mid
# lmd_full/4/41095c09d51b55c65f793eb678db2ceb.mid
# lmd_full/4/444657770bbb247d933b87700c80d96b.mid
# lmd_full/4/49b4f11fbf6133f775ce51ac515984c3.mid
# lmd_full/4/4c53ee261d4574ffe78dcba8ab1d5cb5.mid
# lmd_full/4/4ed42b448f3aadcb874c46dbe93428f6.mid
# lmd_full/4/486ec75fe2848d541ffb726cb5ae5973.mid
# lmd_full/4/4bcdd64a03a3a0eecb7c527103359ee5.mid
# lmd_full/4/4dc04a08899a2d39f84199206b4584b1.mid
# lmd_full/4/4980700f0abd61091a6de5a3a22f148e.mid
# lmd_full/4/4338abace065af91aa00a7c4ede9b2e0.mid
# lmd_full/4/4dffa7cdae14456fb7733bdb0df5e165.mid
# lmd_full/4/42bfafba9a8a13a42cc88c9985fc71ec.mid
# lmd_full/4/46fad9bd4d326107f6b44160e5f412ea.mid
# lmd_full/4/4e6dcdbe91908a4706bb1ec526013b06.mid
# lmd_full/4/4380e8e3bee41dd7676645478557ce5d.mid
# lmd_full/4/4516cf1dee139727f00176b9a832c038.mid
# lmd_full/4/41b6c9f28d960e1f97a8b73384eda859.mid
# lmd_full/4/4cf3b7c525ea216eb7b545a4e4fdce83.mid
# lmd_full/4/461cfad7e6120d3dc72948285d36ff75.mid
# lmd_full/4/46360c317ec4e56bb189c6ec54f9f43e.mid
# lmd_full/4/45c820534581f8ba5622083a799a4ffc.mid
# lmd_full/4/44bfc94fca27093aeafc0d00644ad12a.mid
# lmd_full/4/4a48315120669890ccf53fd239065adb.mid
# lmd_full/4/4aaabf8c376c34aaf6aea7f9f2024e13.mid
# lmd_full/4/4454ba058540a4b36e5cdc907e4e9cb3.mid
# lmd_full/4/49dc4dc9ad19f515046da9ecf5de0b39.mid
# lmd_full/4/4b807ce584de24bd56744163cd9fe3c3.mid
# lmd_full/4/4e865dd3ab8e3df6154c480fc71c1f46.mid
# lmd_full/4/4ed2ce98c6e3d9bc6e5534c9c294b217.mid
# lmd_full/4/4d9b82c7f70fc931b88e109a11e73bb9.mid
# lmd_full/4/4d62ea0f8169d721c1f505a8b351577a.mid
# lmd_full/4/474220b36aab26b1665fcabe083f4772.mid
# lmd_full/4/42def2023596a36881306fc23273cbc5.mid
# lmd_full/4/4fa089dc5279f3c0d80c4980a5423a00.mid
# lmd_full/4/4b70f63f78f445d5d28b5b2a39b2b2c4.mid
# lmd_full/4/44195dc976458495953038a05c6a8fd7.mid
# lmd_full/4/40ca7f491805bd35a6c6680d248eca73.mid
# lmd_full/4/49b0d889a75f89d07b103ab84fe4e6f8.mid
# lmd_full/4/44963dc33f44ac7ee35cabac813090ed.mid
# lmd_full/4/44ebcde43c8ae8f698a5cf3ea9e46286.mid
# lmd_full/4/439b1754f9d621bdff84334f72704b6a.mid
# lmd_full/4/4e889878c60112d6cdbee5e0b7d56c2c.mid
# lmd_full/4/4396b1df2360e12e46f1f5cc71d00cfe.mid
# lmd_full/4/4bdd0f087636fa57b92fdb3b63d73a33.mid
# lmd_full/4/4bf5554f7eb5bc825a05cc8564cb791d.mid
# lmd_full/4/45ec1aa495aa0ae3771ef034ce07651b.mid
# lmd_full/4/445cf01021e23a6fe5b5a5ae373dc534.mid
# lmd_full/4/401e0b719ba4ca41cfd062c93285d9a3.mid
# lmd_full/4/448f45392618be868a5a9762a261a973.mid
# lmd_full/4/44d8d0d70613cc1749fe0885d4b5b149.mid
# lmd_full/4/4704b129227dd8b8efce5846b35d1b6a.mid
# lmd_full/4/409890b4f820cedd617603c50f805960.mid
# lmd_full/4/4a9e270606565a699dbb52cdfd5fac54.mid
# lmd_full/4/4bbfc2e504e9b70e766a86175436b26e.mid
# lmd_full/4/44aa0e7fb8204a126a83e2566ff93fcd.mid
# lmd_full/4/4cdad342053d8221c228a7cf4cfd4f1d.mid
# lmd_full/4/4cc7a0545fb26bca39ecd5f71d3df7ff.mid
# lmd_full/4/4d1eb829268ae8235aec659e36326361.mid
# lmd_full/4/4f06cee4096360bd3a11fd29be6589c1.mid
# lmd_full/4/44a5d4e34d26cea88fc49469a8f3466b.mid
# lmd_full/4/43cb83eca0cc305c69a853a49b6284a8.mid
# lmd_full/4/43e726929fe16b4ecf49d2e3839a1765.mid
# lmd_full/4/4a90dde786cc0b2a09bed1c9c132f9cb.mid
# lmd_full/4/443619123aa5345042039cbadae73d64.mid
# lmd_full/4/4e901206fa1f00edc0eede2a1f6b26c6.mid
# lmd_full/4/4985cc2b65f88b7c0283a94d5d969afa.mid
# lmd_full/4/4d2e590a2d702b43fd9645684eabdb05.mid
# lmd_full/4/40feb67320b1946f5114274accbf121a.mid
# lmd_full/4/4e572cc04e994cad3dc33f1bfdb39410.mid
# lmd_full/4/4c27354c77c1dba2f2f744f8baea15c6.mid
# lmd_full/4/4ef0adf11f3af9e6831e3ea7160da109.mid
# lmd_full/4/402cff131b09c9ffa3a2d7e09704fd92.mid
# lmd_full/4/4ae4d6c2701653da11ee2ab178327707.mid
# lmd_full/4/4111c081ba364f8c892a6a0493a3038c.mid
# lmd_full/4/43ec20e86326bd20a7eda2019f18a2b8.mid
# lmd_full/4/475ebc3cbbcb463ad8809b9c1ed6447c.mid
# lmd_full/4/4418fc33c0ca015f79edd82e0fc19a37.mid
# lmd_full/4/4107d8f3423184c872d48566c4cc2a17.mid
# lmd_full/4/4c0d899034b6d101987f83e529e3ef1b.mid
# lmd_full/4/4f62e372de2ce7eb1b8c12940c022ff6.mid
# lmd_full/4/4e47010cfed6c5df03cdc7be3808c3d2.mid
# lmd_full/4/4f7ce4ae85fe724a147aa1263dc4848e.mid
# lmd_full/4/4465a33817c81629b92d5cb8d1013224.mid
# lmd_full/4/46d0129c21a814f686706af7d1c3411d.mid
# lmd_full/4/4a35c34fb655b98d35246e79ef7db0f4.mid
# lmd_full/4/49170661ca791d2048588174822428ba.mid
# lmd_full/4/42795c3b342105be118e5be520323be1.mid
# lmd_full/4/46a8a600a17f4c37b9a4e633f3b2f062.mid
# lmd_full/4/44d62f78a4b5f6e010cdcfd5587dc645.mid
# lmd_full/4/47b0a1ba57e0d6353933eb0809569a0d.mid
# lmd_full/4/442af183701c4cf8e927fe164f2551e9.mid
# lmd_full/4/43bc640cc915210ae53d3b619cc9aa83.mid
# lmd_full/4/4ea1a28fc29db97b69ba9f398121014c.mid
# lmd_full/4/4ba5a7d67cdd5c46adb2dc9f723d0c34.mid
# lmd_full/4/47009fcb774832fed5748e6de8c33d4a.mid
# lmd_full/4/41f424e20c12fb82a134ee5b0ffb4ffb.mid
# lmd_full/4/478d26e01a3f715e771bcc63df646a9a.mid
# lmd_full/4/4b3782f54637e52dbd596f36417b30ab.mid
# lmd_full/4/45473c3ad13f74ca7c3b9cd4c6ac824e.mid
# lmd_full/4/4fe41af04a82c834849f104b3d7bd761.mid
# lmd_full/4/4dd6b7f122eb02123a11b2eaa1dc40e5.mid
# lmd_full/4/460dc4b0aa2f0dfe1586156655672005.mid
# lmd_full/4/404c043926c8a5158e159a10d2002c9b.mid
# lmd_full/4/4501ae7e20049495996ec26da8d0e7d7.mid
# lmd_full/4/4211f468644abd6102a010b57c0781e9.mid
# lmd_full/4/4147e3357370d15b460399215d364ec9.mid
# lmd_full/4/4f5aa2b92d075475113f3836108ba115.mid
# lmd_full/4/417c5eb82e1c9c97080220807ba712b0.mid
# lmd_full/4/43ec3e6cf6d318cc6aee9ad54968c880.mid
# lmd_full/4/4fbcf7474598c74a2283db497a086e40.mid
# lmd_full/4/455b14a92a878d1bcf1cab83b59917e3.mid
# lmd_full/4/4f9a39c8fd89dc6680ebbde42a3e867c.mid
# lmd_full/4/4dbf044ba5467aa0b4278e452761d0a8.mid
# lmd_full/4/4f14bc6d5300840f789ec4948a92e5f9.mid
# lmd_full/4/408cbd70497ed0e0ecb22e479cb3ad42.mid
# lmd_full/4/48b292486a5b31d49447242f316330af.mid
# lmd_full/4/40b54fd43ccf7d814bca247c99f4d87d.mid
# lmd_full/4/40d5caa4cc3c0d6c9f752bc6e9b711df.mid
# lmd_full/4/4c89bd1233da375dffbd90e18b66f3b1.mid
# lmd_full/4/4431cab54f254d7477a117c432f8d865.mid
# lmd_full/4/47208e02148e85128d15c3b70a06d347.mid
# lmd_full/4/46a0fa234a9a532717c095239fd85090.mid
# lmd_full/4/433ea65e85f154370628963a950fa2f7.mid
# lmd_full/4/4abcf1815fc0b0e18d36d13b8871fe23.mid
# lmd_full/4/452721ce4a99e9123ffeda34f606772b.mid
# lmd_full/4/424249ba53b47edddd06f0b60d0dbbfc.mid
# lmd_full/4/49f30b839c48518c4882393028e170f3.mid
# lmd_full/4/4cff353332bc332383a98ab2730e6550.mid
# lmd_full/4/4a7e426c376457ba95635ccadfd007b9.mid
# lmd_full/4/4962fb9c8dfcdd91bf75da9182f91e5e.mid
# lmd_full/4/48a8d892d25cd1450e9252e6548be6e5.mid
# lmd_full/4/4d4da9f314a5b2ea3c105ad114857db4.mid
# lmd_full/4/4b56fafa368436fa70c746f3c287e388.mid
# lmd_full/4/48e00af4915c8feaf579932b10be1f34.mid
# lmd_full/4/40c518b03f585f9654715a1e7268d61e.mid
# lmd_full/4/428ad3939f6a8ac92f285ae7557eb568.mid
# lmd_full/4/4c5d6c79a90a19c858384c6c5966146e.mid
# lmd_full/4/4773f72f968e7aebe647b4b41d4dd6c4.mid
# lmd_full/4/4549fec389818255a1648f016eb484d2.mid
# lmd_full/4/46c5b60e2050c3ee366337ccdfee7157.mid
# lmd_full/4/450b7d9180697304400e2813497a1c25.mid
# lmd_full/4/40c736c78c63bfe3da2631a9df12925b.mid
# lmd_full/4/420eb8dd07dbe3cd20d644092dc98135.mid
# lmd_full/4/4fdfb1ec383bafdea991eecd2ce3400e.mid
# lmd_full/4/41a17958d3b7458bffc352d4485fa414.mid
# lmd_full/4/4d7b85c77e71276b53f5d6fd15dc6b5e.mid
# lmd_full/4/4ad912f7f698fc3f0384115df0a5ea42.mid
# lmd_full/4/4c66ac6e5e8253f628d135b6be8a92b5.mid
# lmd_full/4/40e0c46f357fc745de9055ab4679a9cb.mid
# lmd_full/4/400c1c96b58e1ce610059657dd5d30b5.mid
# lmd_full/4/4ef96750930a69252981d3a8580f9c90.mid
# lmd_full/4/4b47b462c93ca1cc8e6b1096173e7c77.mid
# lmd_full/4/40b8c597a1c57f14bf266891b1586104.mid
# lmd_full/4/4acbd87fd0bdb5bf5d5ad55a4fb66d08.mid
# lmd_full/4/477879304619ae493856022c9e3d0f21.mid
# lmd_full/4/48d1250ee8f2f278808bbbb3ff70d942.mid
# lmd_full/4/4dab37b6c37e4625acbaa87b7245393c.mid
# lmd_full/4/49ca6bbfb6b2eb31313e611fbb9d30b7.mid
# lmd_full/4/4087fc86980c8970036c0a4fa33a2f0f.mid
# lmd_full/4/40ab9c409211c34c9c33f06c47561c3c.mid
# lmd_full/4/467e287a115142ae9f244121841011f2.mid
# lmd_full/4/4bcc6cf66bba69fab8f428452c32934f.mid
# lmd_full/4/40ff6f50d47803af5f245af5d56284d4.mid
# lmd_full/4/4a22c4b23df3534376e50bd50a9248e1.mid
# lmd_full/4/4c24ad56d24f02e98973dbc04c43a732.mid
# lmd_full/4/48ec26b209108dde54be84185d1d4a8e.mid
# lmd_full/4/41cd235ad76ce8c51505ad7244c80f95.mid
# lmd_full/4/454ff9e2fed81d6efb34f813300b3a6e.mid
# lmd_full/4/4b44cef5652d43bac575d10f5d6973fe.mid
# lmd_full/4/4ab32e2f4f9cafe0355b72fa9629ff2e.mid
# lmd_full/4/4022edf058bf3dfaf232d683d0d932a3.mid
# lmd_full/4/461f9279bdced4b387c85f0f0bc0189b.mid
# lmd_full/4/44da46ae0d5925cfe069790776a8cf34.mid
# lmd_full/4/49504208634de8abd2d5577268a47554.mid
# lmd_full/4/4750b298f3416855d7cc872cf1fcb960.mid
# lmd_full/4/4b375189fe00fc3bdcc93dcff378c6c0.mid
# lmd_full/4/403b5229a094859bcb49e92d81d4d38a.mid
# lmd_full/4/47e245ee4a35a55a5641ed975604d5db.mid
# lmd_full/4/48c9d3bed501e79724122270d3e96682.mid
# lmd_full/4/4d0ca9a2d5adf635c0ab4c6b4cb4ee4d.mid
# lmd_full/4/45dc80001596cdbbf88d804a1765d0ef.mid
# lmd_full/4/48355eea588bbe2c6738f740b44bd49b.mid
# lmd_full/4/4dac07e1da0979d7159f16af72eea9ae.mid
# lmd_full/4/425c12733ebc459122caacf7fd18ebf6.mid
# lmd_full/4/4d9f0e672679aea976adf764c5325b58.mid
# lmd_full/4/490bb0d85caf822bc2514ba299994ba2.mid
# lmd_full/4/45941231f16575c368e71c3ed62c8d6a.mid
# lmd_full/4/4597417c323276ae5fc048f71081debb.mid
# lmd_full/4/4bf7751df34435aefd6c00f6a8f028fa.mid
# lmd_full/4/441d4e54f040ec1ee459cd0f99b82a12.mid
# lmd_full/4/4382c01cb2d8acf5af08fda9bbe950a0.mid
# lmd_full/4/4f537c4051a022affe4155bc59d12a48.mid
# lmd_full/4/48135761d7dfa9b8a1e110634675cd28.mid
# lmd_full/4/4066014c8fbcf6487db4537ec8e0a54b.mid
# lmd_full/4/4d5661feeb194abaa1a851e6c8cd7c59.mid
# ...
# lmd_full/4/40416bfacd7f9bce915fa34e26f20735.mid
# lmd_full/4/451ad13d112828af031341c8b1822bf1.mid
# lmd_full/4/481f6aa108bf411313d9c04da0f0ef63.mid
# lmd_full/4/4875cbe4d1e60d52b1920c32f9df73dc.mid
# lmd_full/4/45964bc1234f8f5a234ae427f142e709.mid
# lmd_full/4/413e0da8864c5dfd4e2f4cb6ab7a0aa9.mid
# lmd_full/4/4386fbb57ada054f5d6d09b60188a4a1.mid
# lmd_full/4/47c79472fdb104c68a9bbedceae23656.mid
# lmd_full/4/41256702a8cb1e5fef9535fde2dce0ca.mid
# lmd_full/4/463c8d39202fe5450c968856725c75e2.mid
# lmd_full/4/4b1a434b32fcf6de4f456ae26e2ca335.mid
# lmd_full/4/4d306c465b3236e3c6cd84adcce004dd.mid
# lmd_full/4/414fcdb31688e00aeace041e179fa04b.mid
# lmd_full/4/4928211a0ba66ad0c97c4a819b56624f.mid
# lmd_full/4/45e3a54cdd5c68256cf46c1a6f86ebf9.mid
# lmd_full/4/4bdafe1bbf5e50a2bdbf7ca5841c0154.mid
# lmd_full/4/4f7e17e59c476eb40c413510fdbc53ee.mid
# lmd_full/4/4b96ce0f88e1a768a716d3b2002d42b2.mid
# lmd_full/4/48d4bd6abee1a64efa0313bc97e258b5.mid
# lmd_full/4/4b6ca64992e91edd1460624ed9109c67.mid
# lmd_full/4/4648a90d4add8247ea312c7b8c5f4147.mid
# lmd_full/4/405161481fd3c00724603237de4f9727.mid
# lmd_full/4/4f16e298b2cfa1648a09eaf62daa29f5.mid
# lmd_full/4/4eda5cb85dc01d6f4d9252e100af923c.mid
# lmd_full/4/4fa94f46bc9bb5a04eff678cc601b352.mid
# lmd_full/4/4419fc27d400bcf1056dabc742ae2a25.mid
# lmd_full/4/46f96ee7ca43007a0c0df757b0952c88.mid
# lmd_full/4/44e0b3e3f9b1028802e9a792dd120399.mid
# lmd_full/4/407b7f34bd246988da235f46ded9bade.mid
# lmd_full/4/45649880038653865326ee120392a3a5.mid
# lmd_full/4/4ee74954808041ae39c298f23f3a35a1.mid
# lmd_full/4/4565e8d18e79c0287bdb10599c427230.mid
# lmd_full/4/4dbd59695ee316d22b5c271edaec3a7e.mid
# lmd_full/4/4dd8f35f52ca8f03065e51bbb90e2205.mid
# lmd_full/4/43faa72f53edf9bb5e63eaaf62e7dd3e.mid
# lmd_full/4/454893df880236a0a5ebadf8abbf21f9.mid
# lmd_full/4/4f96ad9b511b29c9f4ef8f00952d1397.mid
# lmd_full/4/4cbc01df1345e0cd05a773f3b8ecee1b.mid
# lmd_full/4/4e4970a3612b61aa95242b56394861d7.mid
# lmd_full/4/49441ee5b2830f13e995c8bad2605812.mid
# lmd_full/4/4630353fd5eef772e008729efc4ecbfd.mid
# lmd_full/4/4ffd8381bbbde64fa0e853b508d64ad2.mid
# lmd_full/4/4a5dd8f6572e0ff3d87276a485258696.mid
# lmd_full/4/4f64b011b7b1154dd523a5d028433042.mid
# lmd_full/4/4bebb0bc8fa1263770e1debb82e203f4.mid
# lmd_full/4/484b90bcdfe6309fbdd7aa6a67e0d814.mid
# lmd_full/4/4a76acda0322ef1d3b969adf66249c34.mid
# lmd_full/4/4557044d0d582ee72b2d4073ec0ade6c.mid
# lmd_full/4/41ef47b495bf561ec168590c026ab8ed.mid
# lmd_full/4/4f7cb71881f194767a97645727425f22.mid
# lmd_full/4/4cb9e7509425ae7f8600d3f344be6dca.mid
# lmd_full/4/40f406326c134a3c95bf075153f609c2.mid
# lmd_full/4/41c4a96938daa9584308591565238b14.mid
# lmd_full/4/4335b6fa6ae6de42707a82b75f314119.mid
# lmd_full/4/491da322c7098c125b1e6bf1a75fa12a.mid
# lmd_full/4/4b7f8024a5c35c540fcbd7d7dca660b4.mid
# lmd_full/4/422c553660359a28145597bf0e0c16f6.mid
# lmd_full/4/483e91c251987b8075b34d139c7b5256.mid
# lmd_full/4/4474ab52bda3f121690022f6d8d633d3.mid
# lmd_full/4/4e32dc970f5f240761374073ee3c0259.mid
# lmd_full/4/4a2145b6b91d0b4e0d29c901a3448704.mid
# lmd_full/4/49cd249f70e68466c839a8a90a0142d1.mid
# lmd_full/4/44d8858fa3927f9a24824fbeb3317088.mid
# lmd_full/4/4fc1ef5b8f316397d28a761ffdd5a110.mid
# lmd_full/4/479ef00d867ce8b6ad62152a04ad3fa5.mid
# lmd_full/4/4c2ea1d4ab915590582b8dd600836bf2.mid
# lmd_full/4/4f66f0d45899c653d4ba9d6b490f3141.mid
# lmd_full/4/46cff59c812c582d5a5d9b7598a95e5a.mid
# lmd_full/4/4456b4ae825846f313dfdb7a60bf553b.mid
# lmd_full/4/4d7601074ca4f4937830b7a083d62230.mid
# lmd_full/4/4d2fcbfb5ad28d5f01220ccae9444e51.mid
# lmd_full/4/4ecbd8383912e1c1fc915e40e8cdad8c.mid
# lmd_full/4/4591cb5061cec44146b4d7b4810c10a8.mid
# lmd_full/4/4b0c755212069cded927d25bbe384317.mid
# lmd_full/4/4813e2193399a3c777bbb1391cff4bdb.mid
# lmd_full/4/4354153f9f43de15c14cb93656366b6b.mid
# lmd_full/4/4606528bfc8e00340332215a031a66ce.mid
# lmd_full/4/4246032f0f1abd2225b7efa62ace9601.mid
# lmd_full/4/4292750d623ff1ff6391092113836be4.mid
# lmd_full/4/456814d77de337de7e336cb78ee6d74e.mid
# lmd_full/4/4fbba657079cb02207c6b0b893a4ed4a.mid
# lmd_full/4/450a804e98fe1f4b47d3c44c741fea56.mid
# lmd_full/4/46a687158dd43baae234a6e5431dceda.mid
# lmd_full/4/4a98aa3fa31591ca31e3a440cc28c8a3.mid
# lmd_full/4/41bb63d9bfe525be0b3bce91abc33467.mid
# lmd_full/4/41375541b5cd483440f82170b28decae.mid
# lmd_full/4/45ed91c9962cd208465883f79022cd6d.mid
# lmd_full/4/4574d57b75932ea8a023926c7cdfcf31.mid
# lmd_full/4/42d96d342f1a03844d57f25082e428af.mid
# lmd_full/4/43bccf71cfc4b5b89cb6c5c1805a846a.mid
# lmd_full/4/421f45c3a6df377c53400499e4d3a973.mid
# lmd_full/4/4c9e88e2c802e0be08b4906de23c5852.mid
# lmd_full/4/4dfc735abcc38f3b15ee795c82adc675.mid
# lmd_full/4/4d9d1a726afe1ebec5790dc8eaf8c93c.mid
# lmd_full/4/408044582095de1362e817a4e51a55ee.mid
# lmd_full/4/43d299261ec436556267cd986045d554.mid
# lmd_full/4/4e06c14c2f8d89f94f75a83b4d7e17dd.mid
# lmd_full/4/487deb7d26e2157d5a0b83897b95e1f4.mid
# lmd_full/4/446beb5f26081fca30aafb66557cdae1.mid
# lmd_full/4/4a5680a43d502a761c6a9e41a3f1bf88.mid
# lmd_full/4/4554a61bf7fa6c11cceaeecf47ddb373.mid
# lmd_full/4/4614637d04dd42576fc1c72cfb7823dc.mid
# lmd_full/4/407213ae5c620b088c78156b044b3618.mid
# lmd_full/4/49b803a7c170e35cc4ae3466284780d8.mid
# lmd_full/4/407559fa9761afd45bbbb34921ec0e3a.mid
# lmd_full/4/40120437a984fb953c5ad6f309af5fc3.mid
# lmd_full/4/4dc071bb405238a93ad0d2879a5d5eac.mid
# lmd_full/4/41b344f531a25ae7469bf0e0ae4f92b3.mid
# lmd_full/4/45ec6078d79fd3cbdb7512408fbe12e0.mid
# lmd_full/4/4ac9a96e9b24cc331ab2e648fdca74c0.mid
# lmd_full/4/4d60906068d9d95f6917d9df0059b6e2.mid
# lmd_full/4/492bce1061c828cd14bd6643780cd57f.mid
# lmd_full/4/417fefa167156a4acf2d36b09dd986b1.mid
# lmd_full/4/4092a299b604bb6fe0592b13e10eb70e.mid
# lmd_full/4/43358916b973d71fae1e824ddcf31a0c.mid
# lmd_full/4/47e2b601e368a050379917b367ca341d.mid
# lmd_full/4/41938550d8335504bd4a9b3e131af9d9.mid
# lmd_full/4/44dbee03d917e2e80ce701d052501244.mid
# lmd_full/4/4831ecfdcad23a4b121c07ed32f14adc.mid
# lmd_full/4/4dc17d53b55dc17fc9a07322f529c3bb.mid
# lmd_full/4/4d27845449799397d78e5c01382cc89b.mid
# lmd_full/4/4bd7501eb813bfe313908dda7f02a68a.mid
# lmd_full/4/487e9a2067929abb828a921cdc32a6bf.mid
# lmd_full/4/41bf7791e4bc893412e38d9f76ca336e.mid
# lmd_full/4/49ffa9226cad94a4c36016be676fe80c.mid
# lmd_full/4/47dbcd568af1159591c22717dc49dfa6.mid
# lmd_full/4/40e616d7b03b7a0f528a08d91f41a7d6.mid
# lmd_full/4/4aaa14fcfb01de564f2340d8a898f0c2.mid
# lmd_full/4/49402babb9db918e22544a4f5668af6f.mid
# lmd_full/4/44b2912f30ce2aae2a69f997324c9bb5.mid
# lmd_full/4/467fd18f03cf2cc0bfbcd2ae6e84b915.mid
# lmd_full/4/4ad4b2305d0bbdcb9b88e33e4de0850b.mid
# lmd_full/4/41c6db4bb22478cd5a25d3b7f76716ae.mid
# lmd_full/4/42b506cd5278a8939fe25c86ccaf35e2.mid
# lmd_full/4/4ab290a938fcb22a56afd46ccd045c96.mid
# lmd_full/4/42ebc4b0709bf529a2f6b89599b84533.mid
# lmd_full/4/44ca08c45fecee99efa0a06cabcd141e.mid
# lmd_full/4/4512bf859be30b2abe496d78196717b9.mid
# lmd_full/4/4492f7312fa7778bd8c1f94289fa1efb.mid
# lmd_full/4/4dbb76838b8d70d2f096d91afc807a95.mid
# lmd_full/4/4a007fcb8927cf9396020456c65451d5.mid
# lmd_full/4/4bee52f6dc378f4724b8d8e4a96c0b1f.mid
# lmd_full/4/418f00a6b7268a34176a5d88aac7c940.mid
# lmd_full/4/47643163f5d917c03d8e1bf5dab65042.mid
# lmd_full/4/41e0b50ee41a754e7fb77b561b2bb433.mid
# lmd_full/4/4e71a045e2913ad814de4771e55bb1d8.mid
# lmd_full/4/4efd59ec29c40ea50ff5ad1d2e61d334.mid
# lmd_full/4/4a66acb5920329e5441a72ab2d165aa6.mid
# lmd_full/4/45cb1a5d65d25472e2c19ec1d398960b.mid
# lmd_full/4/4cdc8033ca5a62711f819ccb8f921c71.mid
# lmd_full/4/4e7763bb3370a1d8126ca2fdb8ee1cd5.mid
# lmd_full/4/414af845a972b46cd56de4cd464247d3.mid
# lmd_full/4/494fb56811817ba4ad464964b7033ade.mid
# lmd_full/4/40289ecd5fe23bd12a1109673760b5d9.mid
# lmd_full/4/43557aa439361fae642730368f14ff07.mid
# lmd_full/4/4ba3db8ab61e36aba84e89ef5294dd5b.mid
# lmd_full/4/4c7281fde375f290c9f92712d440771a.mid
# lmd_full/4/44bb49080c6e4c776a0f33e79b03c3cc.mid
# lmd_full/4/471379c76b581e132b16d5c8f1f40df9.mid
# lmd_full/4/4b224dd0ab4d67352615350beaa4695c.mid
# lmd_full/4/4a72a87628ae4796d21f2100aac3f219.mid
# lmd_full/4/4122bfbe3324a8c11da1d7864c373400.mid
# lmd_full/4/4eb2398a9a6fa3a0c6fc8c7006c769f2.mid
# lmd_full/4/4b00e3f76dd17959068e9a9e85694480.mid
# lmd_full/4/406e700bc767e7c189a4d56600a5d6b8.mid
# lmd_full/4/4e9fbaa5532e60f5f6d0f6cb5df20831.mid
# lmd_full/4/411b87dc1e18b02db09b20e28018a015.mid
# lmd_full/4/4e3711f5380997ec12e81f24b0d40099.mid
# lmd_full/4/410911bddd6e649b57865c6c54e83c94.mid
# lmd_full/4/4ea03a96ed13ba08bf9efce75f1c5e46.mid
# lmd_full/4/46a108f53f3607ba098fa4c8ffb64051.mid
# lmd_full/4/448a20cb249e1e2036559cddf2ae358c.mid
# lmd_full/4/401457630d795b8dfc9cad88dd95cb23.mid
# lmd_full/4/4e38ae98758289d73940b3fc8491728a.mid
# lmd_full/4/4f61392ffbb245a7105b1a10be7540a0.mid
# lmd_full/4/4ac6091e2da520ee3d5a6b52c4a48dd0.mid
# lmd_full/4/444cffbf1886ef55bc479a54af2527bd.mid
# lmd_full/4/432bf79882ec169e5906de2de5f56874.mid
# lmd_full/4/4f29e4e4bf79b55b8b1778d75e9047c9.mid
# lmd_full/4/42bedac1f625172064ff85e19fb0ee5c.mid
# lmd_full/4/4c9aca1ea2a83bd5f0a9552aebc8487a.mid
# lmd_full/4/4ba25646451d7b019c11b39e3520559c.mid
# lmd_full/4/435354e9c61a582913c0b2ccc4c5e354.mid
# lmd_full/4/49954d5334d77736816a8657345d6204.mid
# lmd_full/4/4ab7575ef333427844106503f81b1dec.mid
# lmd_full/4/40cd5158a36094e30d93f26028222815.mid
# lmd_full/4/49aa319bba2d9691c3352df17a6c346f.mid
# lmd_full/4/46cb5e5ad28af9d06bbbf232c6c6403c.mid
# lmd_full/4/4baf02a5ce6cf910348030fbe62e3945.mid
# lmd_full/4/45a018d7c8c41cf0e7f18d8aa051333d.mid
# lmd_full/4/4fb47b90e5220969d65695a1706373ce.mid
# lmd_full/4/4462b724c336df28dcccda175c3275dd.mid
# lmd_full/4/4fc279a86872a3b313cdfb4139ebe04e.mid
# lmd_full/4/4f080acbf65e320521e3a5d3f2757322.mid
# lmd_full/4/48d683b56cc9ed2e4a0f72cd58f6c353.mid
# lmd_full/4/459566cb8ae812bcc64e6c3792d9d569.mid
# lmd_full/4/461b7964f709ab650c04f82ef3b64784.mid
# lmd_full/4/41a8f4f63c442c7146e2c1baa31a9b2b.mid
# lmd_full/4/43762f320da730d5cf9b57743f0d92d3.mid
# lmd_full/4/4f6e8f2db7ce6882bbb19a0ee325be41.mid
# lmd_full/4/4c2db9f0cba46e3701dfa1d4efa44add.mid
# lmd_full/4/4bb6a81d1a5eea9a38e5ddc9545bae8b.mid
# lmd_full/4/4493bc258c9776ed10ee794389f72a8e.mid
# lmd_full/4/4c8f1a6b9a8a39437745dc08f24483a3.mid
# lmd_full/4/4b19f9f2a48f8b00ce8084829b9ae9f0.mid
# lmd_full/4/484fb6b08a0e05ee4463b30a46a9c229.mid
# lmd_full/4/433c9971b0eba3b06e3f0438741ecb5b.mid
# lmd_full/4/4cdf6863773263fa5d5d340eb5303020.mid
# lmd_full/4/4e2273345214dff509fa5178bd72ec0d.mid
# lmd_full/4/434be53d20a6b21cf3a2ff077c3c6349.mid
# lmd_full/4/4d0c7d0e4de703fb099de72c0bd23235.mid
# lmd_full/4/41f92cc8e8b905ca2b2eb7883d5e4d34.mid
# lmd_full/4/471ede6e30d25416924622c0636c9b12.mid
# lmd_full/4/48f4ece0543a761865721eaa7e1c18ea.mid
# lmd_full/4/4a5f7e7a73e766001d90349e324893de.mid
# lmd_full/4/4c5efc2ec23802306f1ef7964ddd00f4.mid
# lmd_full/4/46bd346bc927591b4f40e7a25220590c.mid
# lmd_full/4/419b452ea6f04ab68a55d488662a66b5.mid
# lmd_full/4/4d1ba3d06e65343f662a43348e29f0bc.mid
# lmd_full/4/41eb547ff10fa85d56ba584843cc65f7.mid
# lmd_full/4/48128b5e17ac4183788a143a9d47c262.mid
# lmd_full/4/416054eda674b757b25e3978e342ea5a.mid
# lmd_full/4/4709600800a84da65cfa74e1d01fced5.mid
# lmd_full/4/4cda3b8e33e1386d87c06eda9639aec3.mid
# lmd_full/4/473f477b83b29f0e5ea621b36e6b2e75.mid
# lmd_full/4/400440a9eadae0bc0497ff37d790117b.mid
# lmd_full/4/48ba5b6032c2ca76f559f7cd5fffe1cc.mid
# lmd_full/4/4a7069c327316283f83a01775d0ed7e7.mid
# lmd_full/4/44335f87de396cb76c7b90b16a02f873.mid
# lmd_full/4/41e4f30e729d65d45632319683f0c7c8.mid
# lmd_full/4/455545b47ddfab65af6bc91cab206ffc.mid
# lmd_full/4/4156c57a204093027574d290c8b29fef.mid
# lmd_full/4/4acbe6ae4ecd33a41a49578aadb182ab.mid
# lmd_full/4/49e9586359d8a2433496f2ce9b182626.mid
# lmd_full/4/42f8192ac630e72360bbf3902c028697.mid
# lmd_full/4/4ebe75d0c5308021e5f85e02c824e64b.mid
# lmd_full/4/471c83427d6d632dc103091102a17183.mid
# lmd_full/4/4c9c3842236e83e6e9da34dbcb21583f.mid
# lmd_full/4/480ae6c85f104c47c82d4904e44f9ffa.mid
# lmd_full/4/4ade4c787bd7a3e9dc4186dfda37eaa5.mid
# lmd_full/4/423b18de7fbf692d860b99df957ebe6d.mid
# lmd_full/4/4f6673b190df23a8988abdf1fe69b40f.mid
# lmd_full/4/45ce8d54685cedbfde08203e17a92b71.mid
# lmd_full/4/4758905c669cae19cefa75566f81bfde.mid
# lmd_full/4/4a93b1c4c20528bd78327b305c43d5c9.mid
# lmd_full/4/41de55dd3232c63d843708e11e30d859.mid
# lmd_full/4/46ae2ffe3e060b679a12f74e05bc6b50.mid
# lmd_full/4/47fa892faf64de4858f1b2076dfa1835.mid
# lmd_full/4/421998fd85fe610c33ee8d2e97ac6743.mid
# lmd_full/4/4d3aaf858b3ed509b1dc46a7938b90bb.mid
# lmd_full/4/43d0ad582bb55f671c31e198b8267f09.mid
# lmd_full/4/4a7ffd3a012a50691cce03fad8dd4871.mid
# lmd_full/4/4d0284bbd64020ac5ca11e6422870703.mid
# lmd_full/4/4f4de656d42e21e3bd17086df330906f.mid
# lmd_full/4/4d71f587bc2b7cc1172332d9be5ce182.mid
# lmd_full/4/49c3032a01dd8be49ee2a8f2ae0f57bd.mid
# lmd_full/4/488d141b15a83320299c2ecdaf6ed998.mid
# lmd_full/4/460ee3de26124dd2e28d6bb2dadf01bf.mid
# lmd_full/4/418b1b1a213d68b0fb7eb234c7bd6eec.mid
# lmd_full/4/480591c6643e8763f64bf51d06e0bfd5.mid
# lmd_full/4/48eb478af0a2d87372a95660b5c70aa2.mid
# lmd_full/4/4cf97d91a2000a51436e5adf57dc394c.mid
# lmd_full/4/4a7380b3c04342a3f02eefad6a6faddf.mid
# lmd_full/4/4cb989528190b616242ea16626345e51.mid
# lmd_full/4/4ce2552d531fc9219ce535e4f414b27a.mid
# lmd_full/4/481eb61486596bd3afc59bd663c59af7.mid
# lmd_full/4/4ff32c017fcc6d89eadb69acfaa9a3a2.mid
# lmd_full/4/46a4c9dcd1701d8b41d9b91a2c3953f5.mid
# lmd_full/4/4fe75ec17a60ba9eeca9c7c180a390d9.mid
# lmd_full/4/466421d7503ab1184d1e8ce6a552674f.mid
# lmd_full/4/4e2734a246fa6ad8efd0fa6c9082b9a2.mid
# lmd_full/4/4e947f2b8a71514b9436e21616d6c5ab.mid
# lmd_full/4/47df514ed4d8de2b57df8b1b02c53d86.mid
# lmd_full/4/4585dbdb5a936bdc853f72412a699866.mid
# lmd_full/4/4c04bdd6f22106718cb503df8a79ee4c.mid
# lmd_full/4/450e351f80c24c3b5a9089fef4356c96.mid
# lmd_full/4/422c032e29c19b981a18c49c27eea58c.mid
# lmd_full/4/44ac35c2405964e90804b439d057ff89.mid
# lmd_full/4/4d2ed8f10462efa811c9ba6c71329efa.mid
# lmd_full/4/4e8782a06d25ce7fcbf7ba5674fc668c.mid
# lmd_full/4/4d0baf12b37e188dcb9b76f7513f1ea5.mid
# lmd_full/4/437d8531ffeb2178e6f24073ef1a1882.mid
# lmd_full/4/4276ce1aef85b28355c13e8b80ee43dd.mid
# lmd_full/4/4a9f5731585b6bb1f260923a967f8422.mid
# lmd_full/4/4212e42b17ce895ac3dace4d063e27a4.mid
# lmd_full/4/4576cbc488443dab0f83fc9c4876a19c.mid
# lmd_full/4/4b664ffe3169222eb042be3f8992c2a3.mid
# lmd_full/4/4a2f7f043aa08c9ce5a43eac6f0a9f65.mid
# lmd_full/4/4aba4200f9ae50d731ecf9e0c8399641.mid
# lmd_full/4/4372e91d875678ef0e0c8932a70fc52e.mid
# lmd_full/4/4cdf7976d8231be2198b463eb8c98c72.mid
# lmd_full/4/47aa7512de710447d39039121b8cca30.mid
# lmd_full/4/47cd7eb2c7e33ec371b781f8abbbbf73.mid
# lmd_full/4/41dfe44364fec6abc2bf5e99b2131dad.mid
# lmd_full/4/47541a3fa4993d2a2325717337a82f50.mid
# lmd_full/4/47ad770833c9342f329bbf9119551d3b.mid
# lmd_full/4/44153830eaabfdb174644490c87658d9.mid
# lmd_full/4/4b1f21104af281913eaa12a6985301c6.mid
# lmd_full/4/423bb84c96afb42a49fb49fea5b72a71.mid
# lmd_full/4/4db57067fe91ff4729cf6f06d0e71a80.mid
# lmd_full/4/4add2b186ec2700e5f08d039cb539668.mid
# lmd_full/4/42e70892226ee242b444be951e965d14.mid
# lmd_full/4/47752ad231c79fcab74a64434b6b9de2.mid
# lmd_full/4/47c1439cd723b457c9009516ac737279.mid
# lmd_full/4/4b116f70795272d1546a0d3381770565.mid
# lmd_full/4/4436612128539fed76e72f5e0d613676.mid
# lmd_full/4/4c399b429bf1400fddbcd3a69c723216.mid
# lmd_full/4/4093623364ec6c11640f6ef7fa53578a.mid
# lmd_full/4/4cad0f144b4b862f55f7a9512f550458.mid
# lmd_full/4/42ab7c53b82796fb1d276d96afead2d0.mid
# lmd_full/4/43f6644a5404d46cf35e9e30c5df28b3.mid
# lmd_full/4/4eab1b90e087e16c2a38a45cac8edab3.mid
# lmd_full/4/446c049c77e68719953c0b820f265eb1.mid
# lmd_full/4/48d232b924d1910e3f00c5a16173b9e3.mid
# lmd_full/4/46f47dd51182e63f6861c50609f01dae.mid
# lmd_full/4/4d921784e815b6d37e94fca35157e90b.mid
# lmd_full/4/404e8b98784ccedf03506ed394a4db0f.mid
# lmd_full/4/4b92c0017472387bb37419940849a6cb.mid
# lmd_full/4/460646d408e8490e69346332422ac353.mid
# lmd_full/4/423e80388f43a1507f7f76b05d74c477.mid
# lmd_full/4/4b3ba9fecb76181d4e4fc78a81b42f4e.mid
# lmd_full/4/419602a87e40cc678a86ff4614fc14ba.mid
# lmd_full/4/4ba19b2f8560a43e8abe8f303ef078ab.mid
# lmd_full/4/471873223fc854a79af14132fc5911ee.mid
# lmd_full/4/45a130bf8b46a1b8e4b550705e02c1c7.mid
# lmd_full/4/4d6ebf6518766a1c844f9038688adbad.mid
# lmd_full/4/4c550a23e8d9c6ca044ee0bc9affdf50.mid
# lmd_full/4/4f2d68894418ee6013e3f04541f10a48.mid
# lmd_full/4/4ff433a7ceb9b32f2637fe2e4911abe0.mid
# lmd_full/4/4b0a238298aa2392b125ec6cd5b79dc9.mid
# lmd_full/4/452f756c5ae0c1a409c0a461e7f75ee2.mid
# lmd_full/4/45b4d45975e65be66832ea9ccc3eb089.mid
# lmd_full/4/4396d71c8c68d6f0302aa9423cfb21eb.mid

# %% [markdown]
# Extracting the gives a very large number of .mid files having musical data and we need to convert this to abc files, for which I am using abc2midi library.

# %%
# !wget -q https://sourceforge.net/projects/abcmidi/files/latest/download -O abcmidi.tar.gz
# !pip install miditoolkit tqdm
# !apt-get update
# !apt-get install -y build-essential
# !apt-get install -y libarchive-tools
# !bsdtar -xf abcmidi.tar.gz
# %cd abcmidi
# !make
# Out:
# Collecting miditoolkit
#   Downloading miditoolkit-1.0.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from miditoolkit) (3.10.0)
# Collecting mido>=1.1.16 (from miditoolkit)
#   Downloading mido-1.3.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.12/dist-packages (from miditoolkit) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mido>=1.1.16->miditoolkit) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->miditoolkit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->miditoolkit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->miditoolkit) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->miditoolkit) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->miditoolkit) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->miditoolkit) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->miditoolkit) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->miditoolkit) (1.17.0)
# Downloading miditoolkit-1.0.1-py3-none-any.whl (24 kB)
# Downloading mido-1.3.3-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: mido, miditoolkit
# Successfully installed miditoolkit-1.0.1 mido-1.3.3
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,202 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,623 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,532 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,598 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,961 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,185 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,410 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,287 kB]
# Get:21 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,848 kB]
# Fetched 38.0 MB in 4s (9,608 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# 0 upgraded, 0 newly installed, 0 to remove and 48 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libarchive-tools
# 0 upgraded, 1 newly installed, 0 to remove and 48 not upgraded.
# Need to get 61.1 kB of archives.
# After this operation, 209 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libarchive-tools amd64 3.6.0-1ubuntu1.5 [61.1 kB]
# Fetched 61.1 kB in 1s (85.6 kB/s)
# Selecting previously unselected package libarchive-tools.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../libarchive-tools_3.6.0-1ubuntu1.5_amd64.deb ...
# Unpacking libarchive-tools (3.6.0-1ubuntu1.5) ...
# Setting up libarchive-tools (3.6.0-1ubuntu1.5) ...
# Processing triggers for man-db (2.10.2-1) ...
# /content/abcmidi
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o parseabc.o parseabc.c
# parseabc.c: In function ‘parsemusic’:
# parseabc.c:2590:53: warning: ‘%s’ directive output may be truncated writing up to 79 bytes into a region of size 67 [-Wformat-truncation=]
#  2590 |           snprintf(error_message, 80, "Unexpected :|%s found", replist);
#       |                                                     ^~
# ......
#  2762 |                   check_and_call_bar (REP_BAR, playonrep_list);
#       |                                                ~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from parseabc.c:36:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:71:10: note: ‘__builtin___snprintf_chk’ output between 20 and 99 bytes into a destination of size 80
#    71 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    72 |                                    __glibc_objsize (__s), __fmt,
#       |                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    73 |                                    __va_arg_pack ());
#       |                                    ~~~~~~~~~~~~~~~~~
# parseabc.c:2581:79: warning: ‘%s’ directive output may be truncated writing up to 79 bytes into a region of size 41 [-Wformat-truncation=]
#  2581 |           snprintf(error_message, 80, "Missing repeat at start ? Unexpected :|%s found", replist);
#       |                                                                               ^~
# ......
#  2762 |                   check_and_call_bar (REP_BAR, playonrep_list);
#       |                                                ~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from parseabc.c:36:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:71:10: note: ‘__builtin___snprintf_chk’ output between 46 and 125 bytes into a destination of size 80
#    71 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    72 |                                    __glibc_objsize (__s), __fmt,
#       |                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    73 |                                    __va_arg_pack ());
#       |                                    ~~~~~~~~~~~~~~~~~
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o store.o store.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o genmidi.o genmidi.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o midifile.o midifile.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o queues.o queues.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o parser2.o parser2.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o stresspat.o stresspat.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o music_utils.o music_utils.c
# gcc -DANSILIBS  -O2   -o abc2midi parseabc.o store.o genmidi.o midifile.o queues.o parser2.o stresspat.o music_utils.o -lm -lm
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o midi2abc.o midi2abc.c
# midi2abc.c: In function ‘txt_metatext’:
# midi2abc.c:833:48: warning: ‘__builtin___snprintf_chk’ output may be truncated before the last format character [-Wformat-truncation=]
#   833 |         snprintf(buffer2, sizeof(buffer2), " %s", textbuff); /*[SDG] 2020-06-03*/
#       |                                                ^
# In file included from /usr/include/stdio.h:894,
#                  from midi2abc.c:56:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:71:10: note: ‘__builtin___snprintf_chk’ output between 2 and 201 bytes into a destination of size 200
#    71 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    72 |                                    __glibc_objsize (__s), __fmt,
#       |                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    73 |                                    __va_arg_pack ());
#       |                                    ~~~~~~~~~~~~~~~~~
# gcc -DANSILIBS  -O2   -o midi2abc midifile.o midi2abc.o  -lm
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o toabc.o toabc.c
# gcc -DANSILIBS  -O2   -o abc2abc parseabc.o toabc.o music_utils.o -lm
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o mftext.o mftext.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o crack.o crack.c
# gcc -DANSILIBS  -O2   -o mftext midifile.o mftext.o crack.o -lm
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o yapstree.o yapstree.c
# yapstree.c: In function ‘event_init’:
# yapstree.c:1247:43: warning: ‘__builtin_snprintf’ output may be truncated before the last format character [-Wformat-truncation=]
#  1247 |     snprintf(outputname,MAX_OUTPUTROOT,"%s", argv[1]);
#       |                                           ^
# In file included from /usr/include/stdio.h:894,
#                  from yapstree.c:26:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:71:10: note: ‘__builtin_snprintf’ output between 1 and 251 bytes into a destination of size 250
#    71 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    72 |                                    __glibc_objsize (__s), __fmt,
#       |                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    73 |                                    __va_arg_pack ());
#       |                                    ~~~~~~~~~~~~~~~~~
# yapstree.c:1236:44: warning: ‘__builtin_snprintf’ output may be truncated before the last format character [-Wformat-truncation=]
#  1236 |     snprintf(outputname, MAX_OUTPUTROOT,"%s",argv[filearg]);
#       |                                            ^
# In file included from /usr/include/stdio.h:894,
#                  from yapstree.c:26:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:71:10: note: ‘__builtin_snprintf’ output between 1 and 251 bytes into a destination of size 250
#    71 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    72 |                                    __glibc_objsize (__s), __fmt,
#       |                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    73 |                                    __va_arg_pack ());
#       |                                    ~~~~~~~~~~~~~~~~~
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o drawtune.o drawtune.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o debug.o debug.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o pslib.o pslib.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o position.o position.c
# gcc -DANSILIBS  -O2   -o yaps parseabc.o yapstree.o drawtune.o debug.o pslib.o position.o parser2.o music_utils.o -lm
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o midicopy.o midicopy.c
# gcc -DANSILIBS  -O2   -o midicopy midicopy.o -lm
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o abcmatch.o abcmatch.c
# gcc -DANSILIBS  -O2   -DHAVE_CONFIG_H  -I.   -c -o matchsup.o matchsup.c
# gcc -DANSILIBS  -O2   -o abcmatch abcmatch.o matchsup.o parseabc.o music_utils.o -lm

# %%
# !apt install abcmidi
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   abcm2ps timidity | pmidi postscript-viewer
# The following NEW packages will be installed:
#   abcmidi
# 0 upgraded, 1 newly installed, 0 to remove and 48 not upgraded.
# Need to get 306 kB of archives.
# After this operation, 868 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 abcmidi amd64 20220218+ds1-1 [306 kB]
# Fetched 306 kB in 1s (209 kB/s)
# Selecting previously unselected package abcmidi.
# (Reading database ... 121699 files and directories currently installed.)
# Preparing to unpack .../abcmidi_20220218+ds1-1_amd64.deb ...
# Unpacking abcmidi (20220218+ds1-1) ...
# Setting up abcmidi (20220218+ds1-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
import os, glob, subprocess
from tqdm import tqdm

input_dir = "/content/mlproject/data/midicaps"
output_dir = "/content/mlproject/data/abc_fast"
os.makedirs(output_dir, exist_ok=True)

midi_files = glob.glob(input_dir + "/**/*.mid", recursive=True)

failed = []

for i, mf in enumerate(tqdm(midi_files)):
    out = f"{output_dir}/{i:07d}.abc"
    try:
        result = subprocess.run(
            ["midi2abc", mf, "-o", out],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            timeout=15
        )
        if result.returncode != 0:
            failed.append((mf, result.stderr.decode()))
    except subprocess.TimeoutExpired:
        failed.append((mf, "timeout"))
    except Exception as e:
        failed.append((mf, str(e)))

print("Failed conversions:", len(failed))
# Out:
# 100%|██████████| 168385/168385 [12:19<00:00, 227.55it/s]
# Failed conversions: 1439

# %% [markdown]
# So, here most of the files are converted, although there are 1439 files which were not able to convert properly, but since it is less than 1 percent of our entire dataset, we would be moving towards next step.

# %%
import glob

abc_dir = "/content/mlproject/data/abc_fast"
out_path = "/content/mlproject/data/abc_corpus.txt"

files_to_be_merged = glob.glob(abc_dir + "/*.abc")

with open(out_path, "w") as out:
    for f in files_to_be_merged:
        try:
            text = open(f).read()
            out.write(text + "\n\n")
        except:
            continue

print("Merged ABC file saved:", out_path)
# Out:
# Merged ABC file saved: /content/mlproject/data/abc_corpus.txt

# %%
len(os.listdir("/content/mlproject/data/abc_fast"))
# Out:
# 168385

# %% [markdown]
# Here we have a dataset of 168385 abc files, and we need to tokenize them to create our vocabulary, Here we have different tokenizors like sentence tokenization, character tokenizer, but since there is a time constraints, I am creating a regex pattern to tokenize our data.

# %%
# %%writefile /content/mlproject/preprocess/tokenize_abc.py
import re

TOKEN_PATTERN = r"""
    [=^_]+[A-Ga-g][,']*   |
    [A-Ga-g][,']*         |
    z[0-9]*               |
    [0-9]+\/[0-9]+        |
    [0-9]+                |
    \|\:|\:\||\|\||\|     |
    [\[\]\(\)]            |
    [<>]                  |
    [A-Z]\:[^\s]+         |
    [a-zA-Z]+             | 
    .                     |
"""

TOKEN_REGEX = re.compile(TOKEN_PATTERN, re.VERBOSE)

def tokenize_abc(text_to_tokenize: str):
    return TOKEN_REGEX.findall(text_to_tokenize)
# Out:
# Writing /content/mlproject/preprocess/tokenize_abc.py

# %%
import os
from multiprocessing import Pool
from mlproject.preprocess.tokenize_abc import tokenize_abc
from tqdm import tqdm

abc_dir = "/content/mlproject/data/abc"
tok_dir = "/content/mlproject/data/tok3"
os.makedirs(tok_dir, exist_ok=True)

files = [f for f in os.listdir(abc_dir) if f.endswith(".abc")]

def process_file(f):
    try:
        text = open(os.path.join(abc_dir, f)).read()
        tokens = tokenize_abc(text)
        out_fp = os.path.join(tok_dir, f.replace(".abc", ".tok"))
        with open(out_fp, "w") as out:
            out.write(" ".join(tokens))
    except:
        pass

with Pool(processes=24) as pool:
    list(tqdm(pool.imap_unordered(process_file, files), total=len(files)))
# Out:
# 100%|██████████| 168292/168292 [12:23<00:00, 226.49it/s]

# %% [markdown]
# Here, we got 168292 different .tok files our tokenization

# %%
# %%writefile /content/mlproject/preprocess/build_vocab_aggressive.py
import os, json, re
from collections import Counter
from multiprocessing import Pool, cpu_count
from tqdm import tqdm

TOK_DIR = "/content/mlproject/data/tok3"
MAX_VOCAB = 8000
CHUNK_SIZE = 5000
fraction_re = re.compile(r"^\d+\/\d+$")

def normalize(token):
    if len(token) > 20:
        return None
    if fraction_re.match(token):
        return None
    if sum(c.isdigit() for c in token) > 6:
        return None
    return token


def process_chunk(file_list):
    local = Counter()
    path = os.path.join

    for f in file_list:
        try:
            with open(path(TOK_DIR, f)) as fp:
                for tok in fp.read().split():
                    t = normalize(tok)
                    if t:
                        local[t] += 1
        except:
            pass

    return local


if __name__ == "__main__":
    files = [f for f in os.listdir(TOK_DIR) if f.endswith(".tok")]
    print("Found", len(files), "files")

    # aggressive chunking
    chunks = [files[i:i+CHUNK_SIZE] for i in range(0, len(files), CHUNK_SIZE)]
    print("Chunks:", len(chunks))

    workers = min(cpu_count(), 8)
    print("Using workers:", workers)

    master = Counter()

    with Pool(workers) as p:
        for c in tqdm(p.imap_unordered(process_chunk, chunks), total=len(chunks)):
            master.update(c)

    sorted_tokens = [t for t, _ in master.most_common(MAX_VOCAB)]
    vocab = ["<PAD>", "<UNK>"] + sorted_tokens

    with open("/content/mlproject/data/vocab.json", "w") as f:
        json.dump({"vocab": vocab}, f, indent=2)

    print("Vocab size:", len(vocab))
# Out:
# Overwriting /content/mlproject/preprocess/build_vocab_aggressive.py

# %% [markdown]
# This is to create our vocab.json file which will contain the data training vocabulary. I am using muliprocessing threads for fast computations here.

# %%
# %%writefile /content/mlproject/preprocess/create_splits.py
import os, random, json

tok_dir = "/content/mlproject/data/tok3"
out_dir = "/content/mlproject/data"

files = [f for f in os.listdir(tok_dir) if f.endswith(".tok")]
random.shuffle(files)

n = len(files)
train = files[: int(n*0.98)]
val   = files[int(n*0.98): int(n*0.99)]
test  = files[int(n*0.99):]

json.dump(train, open(f"{out_dir}/train_files.json", "w"))
json.dump(val,   open(f"{out_dir}/val_files.json", "w"))
json.dump(test,  open(f"{out_dir}/test_files.json", "w"))

print("Train:", len(train))
print("Val:", len(val))
print("Test:", len(test))
# Out:
# Overwriting /content/mlproject/preprocess/create_splits.py

# %% [markdown]
# Ultimately, I need a single train, test, validation file, for this I am creating the splits and then encoding my dataset.

# %%
# %%writefile /content/mlproject/preprocess/encode_dataset.py
import os
import json
import numpy as np
from tqdm import tqdm

tok_dir = "/content/mlproject/data/tok3"
vocab_data = json.load(open("/content/mlproject/data/vocab.json"))
vocab_list = vocab_data["vocab"]
stoi = {tok: i for i, tok in enumerate(vocab_list)}
unk = stoi.get("<UNK>", 0)


def encode(path):
    with open(path, "r") as f:
        tokens = f.read().split()
    return [stoi.get(tok, unk) for tok in tokens]

base = "/content/mlproject/data"

splits = {
    "train": json.load(open(f"{base}/train_files.json")),
    "val":   json.load(open(f"{base}/val_files.json")),
    "test":  json.load(open(f"{base}/test_files.json")),
}

for name, filelist in splits.items():
    ids = []
    for f in tqdm(filelist, desc=name):
        tok_path = os.path.join(tok_dir, f)
        ids.extend(encode(tok_path))

    arr = np.array(ids, dtype=np.uint32)
    arr.tofile(f"/content/mlproject/data/{name}.bin")
    print(f"{name}: {len(arr)} tokens")
# Out:
# Overwriting /content/mlproject/preprocess/encode_dataset.py

# %%
# !python /content/mlproject/preprocess/build_vocab_aggressive.py
# Out:
# Found 168292 files
# Chunks: 34
# Using workers: 8
# 100% 34/34 [28:42<00:00, 50.65s/it]
# Vocab size: 8002

# %%
# !python /content/mlproject/preprocess/create_splits.py
# Out:
# Train: 164926
# Val: 1683
# Test: 1683

# %%
# !python /content/mlproject/preprocess/encode_dataset.py
# Out:
# train:  46% 75762/164926 [10:44<04:03, 365.43it/s]^C

# %% [markdown]
# The encoding part stopped here so, I am again using multiprocessing threads for this in order to encode our data faster

# %%
# %%writefile /content/mlproject/preprocess/encode_fast.py
import os, json, numpy as np
from tqdm import tqdm
import random

TOK_DIR = "/content/mlproject/data/tok3"
OUT_DIR = "/content/mlproject/data"
v = json.load(open("/content/mlproject/data/vocab.json"))
vocab = v.get("vocab") or v
stoi = {tok: i for i, tok in enumerate(vocab)}
unk = stoi.get("<UNK>", 1)
files = sorted([f for f in os.listdir(TOK_DIR) if f.endswith(".tok")])
random.shuffle(files)

n = len(files)
train = files[: int(n*0.98)]
val   = files[int(n*0.98): int(n*0.99)]
test  = files[int(n*0.99):]

splits = [("train", train), ("val", val), ("test", test)]

def encode_stream(split, split_files):
    out_path = f"{OUT_DIR}/{split}.bin"
    with open(out_path, "wb") as fout:
        for f in tqdm(split_files, desc=f"Encoding {split}", miniters=1000):
            fp = os.path.join(TOK_DIR, f)
            text = open(fp).read().split()
            ids = np.array([stoi.get(tok, unk) for tok in text], dtype=np.uint32)
            fout.write(ids.tobytes())
    print(f"Finished {split}: wrote {out_path}")

for name, ff in splits:
    encode_stream(name, ff)
# Out:
# Writing /content/mlproject/preprocess/encode_fast.py

# %%
# !python /content/mlproject/preprocess/encode_fast.py
# Out:
# Encoding train: 100% 164926/164926 [32:49<00:00, 83.75it/s]
# Finished train: wrote /content/mlproject/data/train.bin
# Encoding val: 100% 1683/1683 [00:05<00:00, 322.05it/s]
# Finished val: wrote /content/mlproject/data/val.bin
# Encoding test: 100% 1683/1683 [00:05<00:00, 322.63it/s]
# Finished test: wrote /content/mlproject/data/test.bin

# %%
# %%writefile /content/mlproject/preprocess/create_clean_abc.py
import os
import re
from tqdm import tqdm

RAW_DIR = "/content/mlproject/data/abc_fast"
OUT_DIR = "/content/mlproject/data/abc"
os.makedirs(OUT_DIR, exist_ok=True)

VALID_HEADER = re.compile(r"^(X:|T:|M:|L:|K:)", re.MULTILINE)

files = [f for f in os.listdir(RAW_DIR) if f.endswith(".abc")]

for f in tqdm(files):
    fp = os.path.join(RAW_DIR, f)
    try:
        txt = open(fp).read()
        if not VALID_HEADER.search(txt):
            continue
        if not re.search(r"[A-Ga-gz]", txt):
            continue

        open(os.path.join(OUT_DIR, f), "w").write(txt)

    except:
      continue
# Out:
# Overwriting /content/mlproject/preprocess/create_clean_abc.py

# %%
# !python /content/mlproject/preprocess/create_clean_abc.py
# Out:
# 100% 168385/168385 [03:15<00:00, 859.59it/s]

# %%
# %%writefile /content/mlproject/preprocess/tokenize_abc.py
import re

TOKEN_PATTERN = r"""
    [=^_]+[A-Ga-g][,']*     |
    [A-Ga-g][,']*           |
    z[0-9]*                 |
    [0-9]+\/[0-9]+          |
    [0-9]+                  | 
    \|\:|\:\||\|\||\|       |
    [\[\]\(\)]              | 
    [<>]                    | 
    [A-Z]\:[^\s]+           | 
    .                       | 
"""

TOKEN_REGEX = re.compile(TOKEN_PATTERN, re.VERBOSE)

def tokenize_abc(text):
    return TOKEN_REGEX.findall(text)
# Out:
# Overwriting /content/mlproject/preprocess/tokenize_abc.py

# %%
# !find /content/mlproject -maxdepth 4 -name "*files.json"
# Out:
# /content/mlproject/data/val_files.json
# /content/mlproject/data/train_files.json
# /content/mlproject/data/test_files.json

# %%
# !touch /content/mlproject/_init_.py
# !touch /content/mlproject/preprocess/_init_.py

# %%
import sys
sys.path.append("/content/mlproject/preprocess")
try:
    from tokenize_abc import tokenize_abc
    print("OK: tokenize_abc importable")
except Exception as e:
    print("FAIL:",e)
# Out:
# OK: tokenize_abc importable

# %%
# %%writefile /content/tokenize_all_fast.py
import os
import multiprocessing as mp
from tqdm import tqdm
import sys

sys.path.append("/content/mlproject/preprocess")

from tokenize_abc import tokenize_abc

ABC_DIR = "/content/mlproject/data/abc"
TOK_DIR = "/content/mlproject/data/tok3"
os.makedirs(TOK_DIR, exist_ok=True)

files = [f for f in os.listdir(ABC_DIR) if f.endswith(".abc")]

def process_one(ff):
    try:
        with open(os.path.join(ABC_DIR, ff), "r") as f:
            text = f.read()

        tokens = tokenize_abc(text)

        out_path = os.path.join(TOK_DIR, ff.replace(".abc", ".tok"))
        with open(out_path, "w") as o:
            o.write(" ".join(tokens))

        return 1
    except Exception as e:
        return f"ERROR: {ff} | {e}"

if _name_ == "_main_":
    print("Total files:", len(files))
    pool = mp.Pool(mp.cpu_count())

    for result in tqdm(pool.imap_unordered(process_one, files), total=len(files)):
        if isinstance(result, str) and result.startswith("ERROR"):
            print(result)

    pool.close()
    pool.join()
# Out:
# Overwriting /content/mlproject/preprocess/tokenize_all.py

# %%
# !zip /content/dataset_small.zip \
    /content/mlproject/data/train.bin \
    /content/mlproject/data/val.bin \
    /content/mlproject/data/test.bin \
    /content/mlproject/data/vocab.json \
    /content/mlproject/data/train_files.json \
    /content/mlproject/data/val_files.json \
    /content/mlproject/data/test_files.json
# Out:
#   adding: content/mlproject/data/train.bin (deflated 98%)
#   adding: content/mlproject/data/val.bin (deflated 94%)
#   adding: content/mlproject/data/test.bin (deflated 94%)
#   adding: content/mlproject/data/vocab.json (deflated 73%)
#   adding: content/mlproject/data/train_files.json (deflated 77%)
#   adding: content/mlproject/data/val_files.json (deflated 76%)
#   adding: content/mlproject/data/test_files.json (deflated 76%)

# %% [markdown]
# This created a good dataset having train.bin, test.bin, val.bin, vocab.json. I am storing this in a drive and then moving further in next notebooks as I would a fresh GPU.
